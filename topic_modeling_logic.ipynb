# %%
import requests
from bs4 import BeautifulSoup
import json
import random

# %%
def crawling(word):
    url = "https://relatedwords.org/relatedto/" + word
    html = requests.get(url)
    soup = BeautifulSoup(html.text, "html.parser")
    related_word_json = str(soup.find("script", id="preloadedDataEl")).replace('<script id="preloadedDataEl" type="text/json">', "").replace("</script>", "")
    related_word_json = json.loads(related_word_json)
    related_word = [i["word"] for i in related_word_json["terms"]]
    return related_word
    

crawling("computer")
# Out:
# ['calculator',
#  'machine',
#  'analog computer',
#  'computing',
#  'personal computer',
#  'programmer',
#  'central processing unit',
#  'computer science',
#  'peripheral',
#  'hardware',
#  'mainframe',
#  'microprocessor',
#  'laptop',
#  'vacuum tube',
#  'machine code',
#  'computer program',
#  'server',
#  'computer programming',
#  'memory',
#  'integrated circuit',
#  'turing machine',
#  'charles babbage',
#  'abacus',
#  'electronics',
#  'astrolabe',
#  'cpu',
#  'information',
#  'home computer',
#  'computer hardware',
#  'internet',
#  'pc',
#  'slide rule',
#  'computation',
#  'supercomputer',
#  'transistor',
#  'turing-complete',
#  'floppy disk',
#  'imac',
#  'compiler',
#  'arithmetic',
#  'processor',
#  'john von neumann',
#  'keyboard',
#  'data',
#  'monitor',
#  'predictor',
#  'digital computer',
#  'digital communication',
#  'bit',
#  'data converter',
#  'diskette',
#  'control flow',
#  'james thomson',
#  'mechanical computer',
#  'number cruncher',
#  'visual display unit',
#  'computer circuit',
#  'chip',
#  'information age',
#  'expansion slot',
#  'input device',
#  'peripheral device',
#  'alpha test',
#  'beta test',
#  'antikythera mechanism',
#  'computer memory',
#  'figurer',
#  'estimator',
#  'automation',
#  'macintosh',
#  'reckoner',
#  'loom',
#  'minicomputer',
#  'microcomputer',
#  'electronic computer',
#  'information processing system',
#  'data processor',
#  'digital',
#  'boolean logic',
#  'ibm',
#  'bios',
#  'ibook',
#  'scratchpad',
#  'software',
#  'antivirus',
#  'cyber',
#  'wire',
#  'bus',
#  'world war ii',
#  'desktop',
#  'techie',
#  'machines',
#  'digital data',
#  'embedded system',
#  'handheld',
#  'graphics',
#  'intel',
#  'files',
#  'desktop computer',
#  'washing machine',
#  'business',
#  'laptop computer',
#  'word processor',
#  'personal digital assistant',
#  'algorithm',
#  'operating system',
#  'tide-predicting machine',
#  'william thomson, 1st baron kelvin',
#  'differential analyser',
#  'vannevar bush',
#  'arithmetic logic unit',
#  'mouse',
#  'alan turing',
#  'smartphone',
#  'universal turing machine',
#  'von neumann architecture',
#  'instruction',
#  'printer',
#  'output',
#  'human',
#  'history',
#  'battery',
#  'binary numeral system',
#  'motherboard',
#  'turing complete',
#  'vehicle',
#  'babylonia',
#  'telephone exchange',
#  'compute',
#  'crete',
#  'pda',
#  'storage',
#  'faceplate',
#  'plotter',
#  'outage',
#  'platform',
#  'floppy',
#  'console',
#  'microchip',
#  'compatible',
#  'crt',
#  'interconnection',
#  'format',
#  'site',
#  'website',
#  'readout',
#  'throughput',
#  'formatting',
#  'node',
#  'guest',
#  'client',
#  'incompatible',
#  'pass',
#  'actuary',
#  'adder',
#  'slot',
#  'host',
#  'up',
#  'expert',
#  'module',
#  'store',
#  'hipparchus',
#  'cybernetic',
#  'calendar',
#  'gear',
#  'news',
#  'isfahan',
#  'telnet',
#  'persia',
#  'vm',
#  'computers',
#  'computable',
#  'computational',
#  'computerology',
#  'sector',
#  'computerologist',
#  'computerist',
#  'computernik',
#  'noncomputer',
#  'nanocomputer',
#  'teletype',
#  'computerdom',
#  'puter',
#  'computeritis',
#  'precomputer',
#  'compy',
#  'anticomputer',
#  'neurocomputer',
#  'logarithm',
#  'login',
#  'hostmaster',
#  'function',
#  'machinima',
#  'computerlike',
#  'watchmaker',
#  'mac',
#  'computerism',
#  'neuchâtel',
#  'gnome',
#  'intranet',
#  'switzerland',
#  'computerbased',
#  'computercide',
#  'python',
#  'technology',
#  'softmodem',
#  'telecomputer',
#  'integral',
#  'telecommuter',
#  'cybersavvy',
#  'cybersystem',
#  'multinetworked',
#  'multinetwork',
#  'antikythera',
#  'cyberjunkie',
#  'transistors',
#  'kythera',
#  'screensaver',
#  'cybersociology',
#  'computerize',
#  'cyberterrorism',
#  'cyberintrusion',
#  'cybernetwork',
#  'cyberinteraction',
#  'planisphere',
#  'vdu',
#  'totalizer',
#  'totalizator',
#  'totaliser',
#  'c.p.u.',
#  'totalisator',
#  'busbar',
#  'subtracter',
#  'statistician',
#  'printout',
#  'read-out',
#  'polymath',
#  'electronic',
#  'cyberjargon',
#  'appender',
#  'cybertechnology',
#  'dioptra',
#  'misclick',
#  'devices',
#  'programmable',
#  'netzine',
#  'cyberpsychology',
#  'computing device',
#  'computing machine',
#  'downloader',
#  'applications',
#  'compunications',
#  'clickless',
#  'wardialer',
#  'uploader',
#  'pseudocode',
#  'cyberphilosophy',
#  'pessimize',
#  'systems',
#  'web',
#  'cybersuicide',
#  'mouseclick',
#  'fileserver',
#  'cyberfuture',
#  'planimeter',
#  'cybernate',
#  'cybergeneration',
#  'online',
#  'touchpad',
#  'pcs',
#  'users',
#  'tools',
#  'phones',
#  'logon',
#  'biocomputing',
#  'virtualize',
#  'microsoft',
#  'user',
#  'multimedia',
#  'networking',
#  'artificial intelligence',
#  'cyberimmortality',
#  'e6b',
#  'c++',
#  'device',
#  'tech',
#  'earom',
#  'tool',
#  'incrementor',
#  'scancode',
#  'hackathon',
#  'mit',
#  'uninstall',
#  'mobile',
#  'ambimoustrous',
#  'automata',
#  'computerized',
#  'memex',
#  'sneakernet',
#  'phone',
#  'mathematician',
#  'zodiac',
#  'cyberdating',
#  'uses',
#  'using',
#  'google',
#  'tom kilburn',
#  'system',
#  'dork',
#  'database',
#  'micro',
#  'extranet',
#  'meatware',
#  'portable',
#  'technologies',
#  'equipment',
#  'sophisticated',
#  'interactive',
#  'pointer',
#  'embedded',
#  'audio',
#  'wireless',
#  'metaprogramming',
#  'teleprocessing',
#  'programmers',
#  'servers',
#  'virtual',
#  'graphician',
#  'door',
#  'smart',
#  'transputer',
#  'video',
#  'labs',
#  'available',
#  'makers',
#  'application',
#  'random-access memory',
#  'wired',
#  'drives',
#  'networks',
#  'hour',
#  'boolean algebra',
#  'automated',
#  'tracking',
#  'developed',
#  'product',
#  'sysadmin',
#  'generation',
#  'use',
#  'instance',
#  'communications',
#  'videoterminal',
#  'disk',
#  'search',
#  'rootkit',
#  'robot',
#  'teleinstruction',
#  'submarine',
#  'enabled',
#  'computerphone',
#  'camera',
#  'multitask',
#  'gadgets',
#  'network',
#  'integrated',
#  'cellular',
#  'operating',
#  'workstations',
#  'lever',
#  'processing',
#  'interface',
#  'lab',
#  'components',
#  'advanced',
#  'laptops',
#  'proprietary',
#  'screen',
#  'z2',
#  'day',
#  'university of manchester',
#  'z3',
#  'conditional',
#  'electromechanical',
#  'mobile device',
#  'night',
#  'mobile computing',
#  'relay',
#  'cultural icon',
#  'word',
#  'hertz',
#  'digital audio player',
#  'celluloid',
#  'fighter aircraft',
#  'wave clip',
#  'analog signal',
#  'industrial robot',
#  'organize information',
#  'access internet',
#  'one-to-one correspondence',
#  'traffic light',
#  'finger counting',
#  'in observatory',
#  'tally stick',
#  'engineering',
#  'fertile crescent',
#  'counting rods',
#  'chiclet keyboard',
#  'dumb terminal',
#  'london',
#  'roman abacus',
#  'computer aid design',
#  'at internet cafe',
#  'graphic card',
#  'counting house',
#  'user interface',
#  'surf internet',
#  'process information',
#  'derek j. de solla price',
#  'escape key',
#  'antikythera wreck',
#  'enigma',
#  'word process',
#  'bombe',
#  'memory chip',
#  'stream video',
#  'central process unit',
#  'silicon chip',
#  'internet site',
#  'micro chip',
#  'data structure',
#  'computer accessory',
#  'disk cache',
#  'computer storage',
#  'data formatting',
#  'back up',
#  'analogue computer',
#  'data format',
#  'computer peripheral',
#  'cathode-ray tube',
#  'microprocessor chip',
#  'pari-mutuel machine',
#  'monitoring device',
#  'memory board',
#  'web site',
#  'central processor',
#  'data communication',
#  'electronic device',
#  'star chart',
#  'computer mouse',
#  'hellenistic civilization',
#  'peripheral brain',
#  'web server',
#  'touch screen',
#  'spherical astronomy',
#  'eniac',
#  'von neumann machine',
#  'download manager',
#  'virtual reality',
#  'killer poke',
#  'two finger type',
#  'code monkey',
#  'configuration section',
#  'tv tuner',
#  'abū rayhān al-bīrūnī',
#  'lunisolar calendar',
#  'video card',
#  'in your room',
#  'computer system',
#  'gear train',
#  'machine readable',
#  'command line interpreter',
#  'programming language',
#  'transcendental function',
#  'spread information',
#  'information superhighway',
#  'pierre jaquet-droz',
#  'data process',
#  'database management system',
#  'testbed',
#  'do work',
#  'java programming language',
#  'desktop picture',
#  'window key',
#  'cursor key',
#  'computer graphic',
#  'log in',
#  'ferranti',
#  'concept',
#  'utility program',
#  'differential equations',
#  'amsterdam',
#  'control computer',
#  'ball-and-disk integrator',
#  'job',
#  'write email',
#  'data path',
#  'machine translation',
#  'torque amplifier',
#  'add number',
#  'e transaction',
#  'boot storm',
#  'computer pioneer',
#  'quiche eater',
#  'p 2',
#  'technical support',
#  'difference engine',
#  'third screen',
#  'main memory',
#  'background process',
#  'analytical engine',
#  'process data',
#  'punched card',
#  'harwell',
#  'jacquard loom',
#  'conditional branching',
#  'british government',
#  'hero of alexandria',
#  'astronomical clock',
#  'silicon',
#  'germanium',
#  'television',
#  'telephone',
#  'differential analyzer',
#  'iphone',
#  'edsac',
#  'control systems',
#  'edvac',
#  'hacker',
#  'univac',
#  'carrel',
#  'webcam',
#  'spreadsheet',
#  'disks',
#  'lenovo',
#  'typewriter',
#  'keyboards',
#  'notebook',
#  'typing',
#  'hacking',
#  'databases',
#  'ipod',
#  'bot',
#  'modem',
#  'powerbook',
#  'cellphone',
#  'router',
#  'projector',
#  'compter',
#  'thinkpad',
#  'browser',
#  'whiteboard',
#  'pornography',
#  'kurt gödel',
#  'lunar phase',
#  'flops',
#  'halting problem',
#  'decision problem',
#  'execution',
#  'theory of computation',
#  'branch',
#  'subroutine',
#  'united states navy',
#  'computer data storage',
#  'torpedo data computer',
#  'car',
#  'konrad zuse',
#  'mnemonic',
#  'ada lovelace',
#  'clock frequency',
#  'assembler',
#  'interpreter',
#  'floating point number',
#  'middle ages',
#  'pentium',
#  'binary',
#  'electronic circuit',
#  'hard disk',
#  'tommy flowers',
#  'post office research station',
#  'symbol',
#  'joseph marie jacquard',
#  'keystroke',
#  'workstation',
#  'somniloquy',
#  'keypunch',
#  'symbolics',
#  'copiers',
#  'undelete',
#  'wetware',
#  'photocopier',
#  'wordprocessing',
#  'repairperson',
#  'keystrokes',
#  'whiteboards',
#  'cryptology',
#  'spooler',
#  'passwords',
#  'videodiscs',
#  'recode',
#  'disassembler',
#  'micrographics',
#  'gadget',
#  'flashcard',
#  'electroencephalograph',
#  'initialise',
#  'recognizer',
#  'printouts',
#  'punchcard',
#  'codebreaking',
#  'punch card',
#  'atanasoff–berry computer',
#  'bletchley park',
#  'hang',
#  'cpu cache',
#  'crash',
#  'lorenz sz 40/42',
#  'exploit',
#  'max newman',
#  'computer monitor',
#  'colossus computer',
#  'herman hollerith',
#  'digital electronics',
#  'stored program',
#  'rocket ship',
#  'opcode',
#  'john mauchly',
#  'j. presper eckert',
#  'ram',
#  'instruction set',
#  'national physical laboratory',
#  'microcode',
#  'university of pennsylvania',
#  'first draft of a report on the edvac',
#  'stored-program computer',
#  'victoria university of manchester',
#  'trigonometry',
#  'frederic calland williams',
#  'great britain',
#  'integer',
#  'geoff tootill',
#  'williams tube',
#  'manchester mark 1',
#  'ferranti mark 1',
#  'communication',
#  'negation',
#  'royal dutch shell',
#  'j. lyons and co.',
#  'leo computer',
#  'simd',
#  'science',
#  'matrix',
#  'poison',
#  'netbook',
#  'landfill',
#  'ethernet',
#  'arpanet',
#  'darpa',
#  'sabre',
#  'cryptography',
#  'rendering',
#  'learning',
#  'medicine',
#  'firmware',
#  'nerves',
#  'lead',
#  'semiconductors',
#  'electricity',
#  'interrupt',
#  'byte',
#  'transistor computer',
#  'drum memory',
#  'harwell cadet',
#  'atomic energy research establishment',
#  'royal radar establishment',
#  'ministry of defence',
#  'geoffrey dummer',
#  'washington, d.c.',
#  'jack kilby',
#  'texas instruments',
#  'microsequencer',
#  'robert noyce',
#  'fairchild semiconductor',
#  'marcian hoff',
#  'portable computer',
#  'tablet computer',
#  'electric typewriter',
#  'screen saver',
#  'videocassette recorder',
#  'dot matrix printer',
#  'cell phone',
#  'cassette recorder',
#  'photostat machine',
#  'laser printer',
#  'computer programmer',
#  'binary code',
#  'imperative programming language',
#  'web browser',
#  'superscalar',
#  'mobile phone',
#  'ram machine',
#  'automatic teller machine',
#  'mimd',
#  'multi-core',
#  'photolithography',
#  'microwave oven',
#  'cd player',
#  'mips instruction set',
#  'harvard architecture',
#  'harvard mark i',
#  'assembly language',
#  'natural language',
#  'apple inc.',
#  'processor register',
#  'macintosh 128k',
#  'arm architecture',
#  'handheld video game',
#  'athlon 64',
#  'high-level programming language',
#  'video game console',
#  'computer software',
#  'software engineering',
#  'software bug',
#  'numerical digit',
#  'grace hopper',
#  'harvard mark ii',
#  'control unit',
#  'electrical network',
#  'logic gate',
#  'program counter',
#  'square root',
#  'floating point',
#  'real number',
#  'truth value',
#  'logical conjunction',
#  'logical disjunction',
#  'graphics processing unit',
#  'exclusive or',
#  'euclidean vector',
#  'dna computing',
#  'toxic waste',
#  'waste management',
#  'product stewardship',
#  'computer recycling',
#  'developing nation',
#  'hard drive',
#  'computer network',
#  'ibm pc compatible',
#  'optical computing',
#  'credit card',
#  'identity theft',
#  'semi automatic ground environment',
#  'embarrassingly parallel',
#  'compact disc',
#  'read-only memory',
#  'usb flash drive',
#  'sound card',
#  'vocal cords',
#  'computer speaker',
#  'graphics card',
#  'optical disc drive',
#  'hard disk drive',
#  'flash memory',
#  'machine learning',
#  'computer simulation',
#  "two's complement",
#  "shor's algorithm",
#  'billiard ball computer',
#  'cellular automaton',
#  'computable function',
#  'church–turing thesis',
#  'mainframe computer',
#  'quantum computing',
#  'logic gates',
#  'abstract machine',
#  '3d computer graphics',
#  'computer architecture',
#  'computer networking',
#  'asymmetric digital subscriber line',
#  'wetware computer',
#  'world wide web',
#  'floppy drive']

# %%
topic_modeling = {}

# %%
topic = ["Computer Science", "Social", "Science", "Math", "Sports", "Art", "Music", "Economy", "Physics"]
for i in topic:
    search_word = [i]
    topic_modeling[i] = []

    cnt = 0
    while search_word:
        related_word = crawling(search_word[0])

        if len(related_word) > 20:
            topic_modeling[i].extend(related_word)

            if cnt <= 3:
                search_word.extend(random.sample(related_word, 20))


        del search_word[0]
        cnt += 1

# %%
topic_modeling["Computer Science"]
# Out:
# ['algorithm',
#  'mathematics',
#  'computer engineering',
#  'science',
#  'ibm',
#  'artificial intelligence',
#  'peter j. denning',
#  'code',
#  'computer',
#  'automata theory',
#  'theory of computation',
#  'computer architecture',
#  'computational problem',
#  'computer vision',
#  'software engineering',
#  'computational learning theory',
#  'models of computation',
#  'computational geometry',
#  'logic',
#  'ada lovelace',
#  'mechanical calculator',
#  'information',
#  'integrated circuit',
#  'abacus',
#  'abstraction',
#  'algorithmics',
#  'machine',
#  'numerical analysis',
#  'computing',
#  'eniac',
#  'computation',
#  'arithmometer',
#  'information theory',
#  'computer programming',
#  'information processing',
#  'control flow',
#  'inter-process communication',
#  'transistor',
#  'practical disciplines',
#  'mosfet',
#  'computer graphics',
#  'programming language theory',
#  'complex systems',
#  'human–computer interaction',
#  'ubiquitous',
#  'computer accessibility',
#  'heuristic',
#  'automated planning and scheduling',
#  'digital computer',
#  'wilhelm schickard',
#  'epistemology',
#  'gottfried leibniz',
#  'stepped reckoner',
#  'charles xavier thomas',
#  'informatics',
#  'charles babbage',
#  'difference engine',
#  'alan turing',
#  'analytical engine',
#  'jacquard loom',
#  'bernoulli number',
#  'physics',
#  'herman hollerith',
#  'biology',
#  'tabulating machine',
#  'punched card',
#  'percy ludgate',
#  'mathematical logic',
#  'howard h. aiken',
#  'harvard mark i',
#  'cryptography',
#  'multi-disciplinary',
#  'atanasoff–berry computer',
#  'algebra',
#  'columbia university',
#  'new york city',
#  'cambridge diploma in computer science',
#  'computer hardware',
#  'university of cambridge',
#  'cambridge computer lab',
#  'computational science',
#  'purdue university',
#  'field-effect transistor',
#  'julius edgar lilienfeld',
#  'john bardeen',
#  'walter brattain',
#  'william shockley',
#  'bell labs',
#  'point-contact transistor',
#  'university of manchester',
#  'transistorized computer',
#  'manchester computers',
#  'junction transistor',
#  'probability',
#  'statistics',
#  'mohamed atalla',
#  'dawon kahng',
#  'association for computing machinery',
#  'mosfet scaling',
#  "moore's law",
#  'electrical engineering',
#  'very large-scale integration',
#  'computer revolution',
#  'microcomputer revolution',
#  'computing technology',
#  'csab',
#  'communications of the acm',
#  'linguistics',
#  'harvard business school',
#  'management science',
#  'george forsythe',
#  'peter naur',
#  'data science',
#  'slavic languages',
#  'hungarian language',
#  'greek language',
#  'theory',
#  'edsger w. dijkstra',
#  'cybernetics',
#  'computer system',
#  'semiotics',
#  'neurophysiology',
#  'robotics',
#  'simulation',
#  'proceedings',
#  'software',
#  'information system',
#  'cognitive science',
#  'computational linguistics',
#  'playing cards',
#  'earth science',
#  'computational statistics',
#  'kurt gödel',
#  'john von neumann',
#  'rózsa péter',
#  'alonzo church',
#  'category theory',
#  'domain theory',
#  'david parnas',
#  'peter wegner',
#  'econet',
#  'world war ii',
#  'deductive reasoning',
#  'natural science',
#  'ieee computer society',
#  'symbolic computation',
#  'computability theory',
#  'computational complexity theory',
#  'p versus np problem',
#  'millennium prize problems',
#  'claude shannon',
#  'signal processing',
#  'data compression',
#  'error detection and correction',
#  'linear network coding',
#  'data transmission',
#  'programming language',
#  'formal specification',
#  'language science',
#  'formal verification',
#  'life-critical system',
#  'computer security',
#  'theoretical computer science',
#  'logic in computer science',
#  'formal language',
#  'program semantics',
#  'type systems',
#  'algebraic data types',
#  'applied mathematics',
#  'philosophy of mind',
#  'social intelligence',
#  'software development',
#  'turing test',
#  'petri net',
#  'process calculus',
#  'parallel random-access machine',
#  'database model',
#  'query language',
#  'image processing',
#  'video game',
#  'scientific computing',
#  'scientific modelling',
#  'fluid dynamics',
#  'william j. rapaport',
#  'batch processing',
#  'punched cards',
#  'paper tape',
#  'bbc model b',
#  'o level',
#  'a level',
#  'national curriculum',
#  'united states of america',
#  'computer science teachers association',
#  'inductive reasoning',
#  'logic',
#  'premise',
#  'reasoning',
#  'validity',
#  'argument',
#  'syllogism',
#  'uncertainty',
#  'deduction',
#  'synthesis',
#  'reason',
#  'aristotle',
#  'consequent',
#  'unambiguous',
#  'inductive',
#  'analogical',
#  'inference',
#  'argumentation',
#  'reductionism',
#  'teleological',
#  'computation',
#  'probabilistic',
#  'logical',
#  'specious',
#  'kantian',
#  'aristotelian',
#  'rationality',
#  'intuitive',
#  'predictive',
#  'heuristics',
#  'methodology',
#  'syllogistic',
#  'communicative',
#  'reasoned',
#  'mathematical',
#  'constructs',
#  'axiomatic',
#  'rational',
#  'cogent',
#  'normative',
#  'empirical',
#  'subjective',
#  'validation',
#  'arithmetic',
#  'competency',
#  'case-based',
#  'deterministic',
#  'intuitionistic',
#  'arcane',
#  'fallacious',
#  'turing',
#  'persuasive',
#  'intuition',
#  'analytic',
#  'arguments',
#  'semantics',
#  'metaphysics',
#  'characterization',
#  'interpreting',
#  'simplest',
#  'syntax',
#  'formulation',
#  'parsing',
#  'interpretation',
#  'algorithms',
#  'nonlinear',
#  'causation',
#  'generalization',
#  'summation',
#  'computations',
#  'analogous',
#  'heuristic',
#  'procedural',
#  'prescriptive',
#  'quantum',
#  'competence',
#  'concepts',
#  'theory',
#  'transcendental',
#  'propriety',
#  'abductive',
#  'merits',
#  'constitutionality',
#  'typing',
#  'assumptions',
#  'simplistic',
#  'propounded',
#  'query',
#  'causality',
#  'categorization',
#  'correctness',
#  'impossibility',
#  'methodologies',
#  'judgements',
#  'foundational',
#  'parallelism',
#  'method',
#  'applicability',
#  'complexity',
#  'linear',
#  'iterative',
#  'dictation',
#  'rationale',
#  'abstract thought',
#  'logical thinking',
#  'non-monotonic',
#  'defeasible',
#  'first-order',
#  'propositional calculus',
#  'problem-solving',
#  'hypothesis',
#  'legalistic',
#  'rule-based',
#  'computer-based',
#  'equational',
#  'recusal',
#  'logical necessity',
#  'equality',
#  'closed-world assumption',
#  'soundness',
#  'mathematical induction',
#  'abductive reasoning',
#  'rule of inference',
#  'material conditional',
#  'affirming the consequent',
#  'modus ponens',
#  'rationalism',
#  'term logic',
#  'predicate logic',
#  'ancient greek philosophy',
#  'rené descartes',
#  'discourse on the method',
#  'scientific method',
#  'subtraction',
#  'addition',
#  'calculator',
#  'multiplication',
#  'decimal',
#  'division',
#  'square root',
#  'russia',
#  'china',
#  'india',
#  'hexadecimal',
#  'roman empire',
#  'arithmetic',
#  'mathematics',
#  'blind',
#  'africa',
#  'latin',
#  'tablet',
#  'cube root',
#  'sumer',
#  'number',
#  'babylon',
#  'cuneiform',
#  'herodotus',
#  'sassanian',
#  'iran',
#  'roman abacus',
#  'sexagesimal',
#  'demosthenes',
#  'alexis',
#  'tusk',
#  'polybius',
#  'ivory',
#  'incisor',
#  'hindu–arabic numeral system',
#  'toothed',
#  'tooth',
#  'eastern europe',
#  'premolar',
#  'dentin',
#  'dentition',
#  'aros',
#  'hardwood',
#  'sib',
#  'middle english',
#  'amex',
#  'quadro',
#  'nomura',
#  'cit',
#  'citi',
#  'greek language',
#  'dental',
#  'brokerage',
#  'janus',
#  'cic',
#  'kkr',
#  'rcm',
#  'ebs',
#  'genitive case',
#  'blackstone',
#  'mattes',
#  'toothsome',
#  'csfb',
#  'grammophon',
#  'nikko',
#  'ncb',
#  'northwest semitic',
#  'ergo',
#  'cpm',
#  'structuring',
#  'scm',
#  'molar',
#  'cs',
#  'nyse',
#  'ubs',
#  'unisys',
#  'rtc',
#  'euronext',
#  'aig',
#  'toothless',
#  'esop',
#  'suisse',
#  'phoenician language',
#  'quadrangle',
#  'agora',
#  'lambda',
#  'prospectus',
#  'bca',
#  'underwriters',
#  'derivatives',
#  'securities',
#  'warburg',
#  'cim',
#  'wavefront',
#  'jungian',
#  'hagedorn',
#  'calculating machine',
#  'pma',
#  'hebrew language',
#  'suanpan',
#  'monophyodont',
#  'fang',
#  'toothy',
#  'apothecary',
#  'toothlike',
#  'tine',
#  'multitooth',
#  'toothlet',
#  'toothly',
#  'jaw',
#  'bicuspid',
#  'dws',
#  'teethly',
#  'eyetooth',
#  'etrade',
#  'teethlike',
#  'gagtooth',
#  'lamprey',
#  'uam',
#  'l.p.',
#  'tusker',
#  'corestates',
#  'conodont',
#  'dent',
#  'baybanks',
#  'markoe',
#  'toothing',
#  'heterodont',
#  'indepth',
#  'boerse',
#  'providian',
#  'mandible',
#  'dbp',
#  'börse',
#  'instinet',
#  'daiwa',
#  'ancient egypt',
#  'hauerwas',
#  'pranav',
#  'dialogic',
#  'toothpuller',
#  'underwrote',
#  'lcf',
#  'alveolar',
#  'perella',
#  'mrcc',
#  'bfg',
#  'gum',
#  'silar',
#  'lgt',
#  'menatep',
#  'finova',
#  'metrix',
#  'foretooth',
#  'cog',
#  'achaemenid empire',
#  'cerulli',
#  'laurice',
#  'cognos',
#  'caries',
#  'yamaichi',
#  'ltcb',
#  'rcbc',
#  'seafirst',
#  'norwest',
#  'toothmark',
#  'lipper',
#  'cdse',
#  'wamu',
#  'parthian empire',
#  'lustgarten',
#  'counterparties',
#  'baybank',
#  'sonus',
#  'kirshenbaum',
#  'orling',
#  'postfinance',
#  'bynner',
#  'forschungsgemeinschaft',
#  'cuspid',
#  'citic',
#  'eurex',
#  'bakheet',
#  'itg',
#  'nasd',
#  'kantonalbank',
#  'livedoor',
#  'panamsat',
#  'toothpick',
#  'orthopantomogram',
#  'dentine',
#  'palate',
#  'cementum',
#  'prong',
#  'canine',
#  'edentate',
#  'chaw',
#  'pearly',
#  'toothdrawer',
#  'jawbone',
#  'narwhal',
#  'mastication',
#  'gummy',
#  'serrate',
#  'toothdrawing',
#  'projection',
#  'cud',
#  'wolf',
#  'glossohyal',
#  'toothbrush',
#  'typodont',
#  'dogtooth',
#  'denture',
#  'chewy',
#  'paragnathus',
#  'palatal',
#  'chew',
#  'jackal',
#  'peristome',
#  'toothpaste',
#  'hagfish',
#  'gnash',
#  'diogenes of sinope',
#  'mouthful',
#  'gingiva',
#  'snaggletooth',
#  'fangy',
#  'mesial',
#  '0',
#  'hydroxyapatite',
#  'logarithms',
#  'pencil',
#  'pendulums',
#  'algebraic',
#  'chopsticks',
#  'equations',
#  'pianola',
#  'sextant',
#  'origami',
#  'typewriting',
#  'homophones',
#  'trigonometry',
#  'theorems',
#  'mathematicians',
#  'yantra',
#  'mnemonics',
#  'polynomials',
#  'palmistry',
#  'maths',
#  'trig',
#  'divination',
#  'typewriters',
#  'shogi',
#  'astrolabe',
#  'combinatorics',
#  'kanji',
#  'oracle',
#  'alphabets',
#  'calculations',
#  'treadle',
#  'crayon',
#  'sutras',
#  'spreadsheet',
#  'farthings',
#  'ocarina',
#  'computations',
#  'beads',
#  'daoism',
#  'thimbles',
#  'gramophone',
#  'metronome',
#  'adze',
#  'magic',
#  'scrabble',
#  'katakana',
#  'plaiting',
#  'awl',
#  'masticate',
#  'salamis island',
#  'whelp',
#  'remineralization',
#  'rima',
#  'tridentate',
#  'gomphosis',
#  'salamis tablet',
#  'maxilla',
#  'calcareous',
#  'bitewing',
#  'rex',
#  'champ',
#  'mouth',
#  'comb',
#  'pectinal',
#  'retainer',
#  'labial',
#  'chewstick',
#  'decalcification',
#  'canis',
#  'largemouth',
#  'serration',
#  'milk tooth',
#  'orthodontics',
#  'pearly white',
#  'fauces',
#  'reckon',
#  'back tooth',
#  'canidae',
#  'jeton',
#  'wisdom tooth',
#  'chomp',
#  'midchew',
#  'korea',
#  'canine tooth',
#  'tind',
#  'aztec',
#  'exostosis',
#  'currycomb',
#  'chewer',
#  'nahuatl',
#  'pulp cavity',
#  'dentifrice',
#  'fluorapatite',
#  'teethe',
#  'protractors',
#  'diabolo',
#  'erasers',
#  'mathematic',
#  'inkwells',
#  'chessboards',
#  'ballpoints',
#  'sharpener',
#  'spirograph',
#  'blackboards',
#  'thingamabob',
#  'brail',
#  'adz',
#  'paperclips',
#  'netsuke',
#  'pinecone',
#  'mimeograph',
#  'stopwatch',
#  'noughts',
#  'clicker',
#  'tangram',
#  'moneybox',
#  'zithers',
#  'cloisonne',
#  'brainwork',
#  'eggbeater',
#  'cosines',
#  'samisen',
#  'hourglasses',
#  'flutemouth',
#  'pipemouth',
#  'mouthsore',
#  'mouthward',
#  'mouthwards',
#  'manubrium',
#  'mouthguard',
#  'abhidharmakośabhāṣya',
#  'mouthlike',
#  'chew food',
#  'mouthly',
#  'mouthpart',
#  'mouthless',
#  'carnassial',
#  'along the river during the qingming festival',
#  'taurodontism',
#  'warmouth',
#  'canid',
#  'vasubandhu',
#  'olmec',
#  'molarity',
#  'serrature',
#  'suckermouth',
#  'gap toothed',
#  'vulpine',
#  'zhang zeduan',
#  'mouthy',
#  'houndly',
#  'glyptodon',
#  'crenature',
#  'whitelip',
#  'vasumitra',
#  'salivate',
#  'orad',
#  'panosteitis',
#  'articulography',
#  'in mouth',
#  'bonedog',
#  'tooth fairy',
#  'cynanthropy',
#  'dogbone',
#  'front tooth',
#  'song dynasty',
#  'soroban',
#  'cynophilia',
#  'blabbermouth',
#  'mouthcoating',
#  'cavemouth',
#  'wrymouth',
#  'dogly',
#  'lytta',
#  'autopalatine',
#  'doglike',
#  'dentiphone',
#  'photopolymer',
#  'my mouth',
#  'inca',
#  'gear wheel',
#  'dentary bone',
#  'counting rods',
#  'tooth and nail',
#  'calmecac',
#  'tang dynasty',
#  'indian ocean',
#  'armenians',
#  'napoleon',
#  'blindness',
#  'ascii',
#  'middle east',
#  'hard palate',
#  'decimal point',
#  'low jaw',
#  'quipu',
#  'buccal cavity',
#  'roman numeral',
#  'pig jaw',
#  'oral cavity',
#  'pope sylvester ii',
#  'your mouth',
#  'yupana',
#  "dog's mouth",
#  'bi-quinary coded decimal',
#  'gram molecule',
#  'roman numerals',
#  'eat with',
#  'pythagorean theorem',
#  'electric typewriter',
#  'quadratic equation',
#  'dowsing rod',
#  'blackboard eraser',
#  'leonardo fibonacci',
#  'milking stool',
#  'sewing machine',
#  'quill pen',
#  'sleigh bell',
#  'stud finder',
#  'differential calculus',
#  'prayer beads',
#  'brush wheel',
#  'boolean algebra',
#  'allen wrench',
#  'mandarin dialect',
#  'boolean logic',
#  'thermos flask',
#  'mercator projection',
#  'fine tooth comb',
#  'bush dog',
#  'potty mouth',
#  'salivary gland',
#  'corner tooth',
#  'algorism',
#  'have tooth',
#  'in your mouth',
#  'dental calculus',
#  'lip synch',
#  'wild dog',
#  'service dog',
#  'bevel gear',
#  'fee dog',
#  'electronic calculator',
#  'dog eat dog',
#  'extrude body part',
#  'primary school',
#  'floating point',
#  'maya peoples',
#  'yucatán peninsula',
#  'sylvanus morley',
#  'tally stick',
#  'quechua languages',
#  'whole number',
#  'fibonacci sequence',
#  'commonwealth of independent states',
#  'mechanical calculator',
#  'dutch language',
#  'numeral system',
#  'nemeth braille',
#  'turkic peoples',
#  'jean-victor poncelet',
#  'soviet union',
#  'odhner arithmometer',
#  'pocket calculator',
#  'romania',
#  'uralic languages',
#  'finnish language',
#  'dialect',
#  'linguist',
#  'slovenia',
#  'language family',
#  'lexicon',
#  'hungary',
#  'slovakia',
#  'ukraine',
#  'british english',
#  'european union',
#  'language',
#  'coptic',
#  'bilingual',
#  'multilingual',
#  'serbia',
#  'lexis',
#  'amharic',
#  'hindi',
#  'breton',
#  'oriya',
#  'lingo',
#  'sudovian',
#  'pidgin',
#  'swahili',
#  'intralinguistic',
#  'monoglot',
#  'lect',
#  'macrolanguage',
#  'mansi language',
#  'khanty language',
#  'metalanguage',
#  'patois',
#  'austronesian',
#  'penglish',
#  'spanish',
#  'indic',
#  'terminology',
#  'swedish',
#  'ese',
#  'linguistic',
#  'russian',
#  'balinese',
#  'artificial language',
#  'phraseology',
#  'limburgish',
#  'slanguage',
#  'jargon',
#  'idiolect',
#  'estonian',
#  'etruscan',
#  'latin',
#  'trilingual',
#  'natural language',
#  'sinicism',
#  'linguistic topic',
#  'norse',
#  'profanity',
#  'galician',
#  'argot',
#  'standard language',
#  'english',
#  'germanism',
#  'dead language',
#  'french',
#  'hispanism',
#  'interlanguage',
#  'cambodian',
#  'human language',
#  'danish',
#  'vocabulary',
#  'asturian',
#  'arabic',
#  'latino',
#  'venetian',
#  'frenchism',
#  'auxiliary language',
#  'anglicism',
#  'mother tongue',
#  'nonspeaker',
#  'condela',
#  'mongolian',
#  'tonguage',
#  'romance language',
#  'castilian',
#  'myanmar',
#  'cyberlanguage',
#  'finnish',
#  'estonian language',
#  'kingdom of hungary',
#  'ugric languages',
#  'parlance',
#  'serbo croatian',
#  'pseudoword',
#  'glossolalia',
#  'pennsylvania dutch',
#  'proto indo european',
#  'lingual',
#  'lithuanian',
#  'altaic',
#  'lapp',
#  'sprachgefühl',
#  'aleut',
#  'syncretistic',
#  'afrikaans',
#  'deutsch',
#  'korean',
#  'norwegian',
#  'nominalism',
#  'latinism',
#  'bislama',
#  'walloon',
#  'ukrainian',
#  'indianism',
#  'english plus',
#  'dravidian',
#  'wordstock',
#  'polyglot',
#  'germanic',
#  'tonguely',
#  'comitative',
#  'berber',
#  'philological',
#  'sociolinguistics',
#  'object language',
#  'camouflanguage',
#  'bohemian',
#  'oracy',
#  'cree',
#  'treaty of trianon',
#  'translative',
#  'hybridize',
#  'loanword',
#  'abessive',
#  'idiom',
#  'janglish',
#  'live language',
#  'bashkir',
#  'americanist',
#  'enunciable',
#  'loan translation',
#  'construct language',
#  'sanskrit',
#  'vulgate',
#  'europeanism',
#  'lexical',
#  'arab',
#  'west germanic',
#  'antiverbal',
#  'glossology',
#  'hunglish',
#  'lexicology',
#  'shoshone',
#  'finderlist',
#  'osco umbrian',
#  'speechlore',
#  'indo european',
#  'neurolinguistics',
#  'articulable',
#  'modern english',
#  'negative interference',
#  'ancient greek',
#  'austria',
#  'tok pisin',
#  'non standard speech',
#  'metalinguistics',
#  'lexical semantics',
#  'sabaean',
#  'language lab',
#  'eskimo aleut',
#  'receptive language',
#  'middle english',
#  'european portuguese',
#  'siberia',
#  'official language',
#  'onogurs',
#  'hungarian people',
#  'hungarians',
#  'ural mountains',
#  ...]

# %%
import pandas as pd

# %%
word_list = []
topic_list = []

# %%
topics = topic_modeling.keys()
for t in topics:
    word_list.extend(topic_modeling[t])
    topic_list.extend([t for _ in range(len(topic_modeling[t]))])

# %%
topic_modeling_df = pd.DataFrame(zip(word_list, topic_list), columns=["word", "topic"])

# %%
topic_modeling_df
# Out:
#                                    word             topic
# 0                             algorithm  Computer Science
# 1                           mathematics  Computer Science
# 2                  computer engineering  Computer Science
# 3                               science  Computer Science
# 4                                   ibm  Computer Science
# ...                                 ...               ...
# 270497  third council of constantinople           Physics
# 270498         st. theodore the studite           Physics
# 270499            notitiae episcopatuum           Physics
# 270500               lampsacus treasure           Physics
# 270501                      titular see           Physics
#
# [270502 rows x 2 columns]

# %%
topic_modeling_df.to_csv("./topic_modeling.csv")

# %%
import pandas as pd

# %%
topic_modeling_df = pd.read_csv("./topic_modeling.csv")
topic_modeling_df.drop("Unnamed: 0", axis=1, inplace=True)
topic_modeling_df.head()
# Out:
#                    word             topic
# 0             algorithm  Computer Science
# 1           mathematics  Computer Science
# 2  computer engineering  Computer Science
# 3               science  Computer Science
# 4                   ibm  Computer Science

# %%
algorithm = topic_modeling_df[topic_modeling_df["word"] == "algorithm"].to_numpy()
print(algorithm)
print(len([i for i in algorithm if i[1] == "Computer Science"]))
# Out:
# [['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Computer Science']
#  ['algorithm' 'Science']
#  ['algorithm' 'Science']
#  ['algorithm' 'Science']
#  ['algorithm' 'Math']
#  ['algorithm' 'Math']
#  ['algorithm' 'Math']
#  ['algorithm' 'Math']
#  ['algorithm' 'Math']
#  ['algorithm' 'Sports']
#  ['algorithm' 'Art']]
# 8

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
topic_count = {"Computer Science": 0, "Social": 0, "Science": 0, "Math": 0, "Sports": 0, "Art": 0, "Music": 0, "Economy": 0, "Physics": 0}
topics = topic_count.keys()
sentence = input("Input: ")
words = [i[0] for i in pos_tag(word_tokenize(sentence)) if i[1] in ["NN", "NNP"]]
for word in words:
    topic_word = topic_modeling_df[topic_modeling_df["word"] == word].to_numpy()
    
    for topic in topics:
        topic_count[topic] += len([i for i in topic_word if i[1] == topic])

print(topic_count)
topic = sorted(topic_count.items(), key=lambda x: x[1], reverse=True)

for i in range(len(topics)):
    print(f"{i+1}. {topic[i][0]}: {topic[i][1] / sum([i[1] for i in topic]) * 100}")
# Out:
# Input: Neuralink's technology, to be clear, looks awesome. It's a brain implant the size of four dollar coins with more than 1,000 electrodes that will (someday) allow a person to wirelessly send neuroelectrical activity to anything digital, from prosthetic arms to Tesla autopilots to memory-recording cloud servers.
# {'Computer Science': 9, 'Social': 18, 'Science': 37, 'Math': 17, 'Sports': 4, 'Art': 11, 'Music': 11, 'Economy': 27, 'Physics': 2}
# 1. Science: 27.205882352941174
# 2. Economy: 19.852941176470587
# 3. Social: 13.23529411764706
# 4. Math: 12.5
# 5. Art: 8.088235294117647
# 6. Music: 8.088235294117647
# 7. Computer Science: 6.61764705882353
# 8. Sports: 2.941176470588235
# 9. Physics: 1.4705882352941175

# %%
search_word = ["Person"]
person_word = []

cnt = 0
while search_word:
    related_word = crawling(search_word[0])

    if len(related_word) > 20:
        person_word.extend(related_word)

        if cnt <= 3:
            search_word.extend(random.sample(related_word, 20))


    del search_word[0]
    cnt += 1
    
person_word
# Out:
# ['people',
#  'someone',
#  'child',
#  'adult',
#  'worker',
#  'individual',
#  'reason',
#  'personality',
#  'subject',
#  'philosophy',
#  'anyone',
#  'man',
#  'woman',
#  'one',
#  'patient',
#  'victim',
#  'language',
#  'female',
#  'mammal',
#  'primate',
#  'somebody',
#  'soul',
#  'mortal',
#  'chimpanzee',
#  'orangutan',
#  'brain',
#  'native',
#  'self',
#  'applicant',
#  'inhabitant',
#  'animal',
#  'appointee',
#  'else',
#  'everyone',
#  'thing',
#  'nobody',
#  'she',
#  'morality',
#  'face',
#  'black',
#  'white',
#  'gorilla',
#  'property',
#  'being',
#  'leader',
#  'friend',
#  'legs',
#  'family',
#  'idea',
#  'emotion',
#  'community',
#  'human',
#  'pelvis',
#  'another',
#  'customs',
#  'life',
#  'thought',
#  'not',
#  'any',
#  'how',
#  'couple',
#  'having',
#  'good',
#  'art',
#  'literature',
#  'guy',
#  'music',
#  'organism',
#  'employee',
#  'creature',
#  'user',
#  'entity',
#  'player',
#  'type',
#  'those',
#  'law',
#  'character',
#  'customer',
#  'genetics',
#  'hominid',
#  'chad',
#  'car',
#  'europe',
#  'hunter-gatherer',
#  'war',
#  'death',
#  'extinct',
#  'species',
#  'latin',
#  'order',
#  'consciousness',
#  'mother',
#  'bipedal',
#  'month',
#  'kinship',
#  'arm',
#  'ownership',
#  'walking',
#  'tool',
#  'continent',
#  'million',
#  'earth',
#  'instinct',
#  'cause',
#  'anatomy',
#  'bod',
#  'build',
#  'chassis',
#  'figure',
#  'flesh',
#  'form',
#  'frame',
#  'physique',
#  'shape',
#  'soma',
#  'adventurer',
#  'anomaly',
#  'anachronism',
#  'appointment',
#  'capitalist',
#  'captor',
#  'changer',
#  'modifier',
#  'commoner',
#  'communicator',
#  'contestant',
#  'coward',
#  'creator',
#  'controversialist',
#  'disputant',
#  'engineer',
#  'technologist',
#  'entertainer',
#  'experimenter',
#  'expert',
#  'individualist',
#  'denizen',
#  'dweller',
#  'habitant',
#  'aboriginal',
#  'aborigine',
#  'innocent',
#  'intellect',
#  'intellectual',
#  'juvenile',
#  'lover',
#  'male',
#  'national',
#  'compeer',
#  'equal',
#  'match',
#  'peer',
#  'beholder',
#  'observer',
#  'percipient',
#  'forerunner',
#  'precursor',
#  'primitive',
#  'sensualist',
#  'traveler',
#  'traveller',
#  'unfortunate',
#  'african',
#  'caucasian',
#  'amerindian',
#  'slav',
#  'gentile',
#  'hebrew',
#  'israelite',
#  'aries',
#  'ram',
#  'bull',
#  'taurus',
#  'gemini',
#  'twin',
#  'cancer',
#  'crab',
#  'leo',
#  'lion',
#  'virgin',
#  'virgo',
#  'balance',
#  'libra',
#  'scorpio',
#  'scorpion',
#  'archer',
#  'sagittarius',
#  'capricorn',
#  'goat',
#  'aquarius',
#  'fish',
#  'pisces',
#  'abomination',
#  'abstainer',
#  'achiever',
#  'success',
#  'winner',
#  'acquaintance',
#  'active',
#  'actor',
#  'doer',
#  'adjudicator',
#  'admirer',
#  'adversary',
#  'antagonist',
#  'opponent',
#  'opposer',
#  'advocate',
#  'exponent',
#  'proponent',
#  'agnostic',
#  'doubter',
#  'albino',
#  'amateur',
#  'ancient',
#  'anti',
#  'asthmatic',
#  'authority',
#  'automaton',
#  'learning',
#  'childhood',
#  'birth',
#  'personhood',
#  'sign',
#  'abstraction',
#  'hominidae',
#  'communication',
#  'laws',
#  'self-consciousness',
#  'tradition',
#  'world',
#  'myth',
#  'science',
#  'fire',
#  'cooking',
#  'food',
#  'clothes',
#  'technology',
#  'beauty',
#  'nation',
#  'grownup',
#  'venturer',
#  'applier',
#  'capturer',
#  'eristic',
#  'indweller',
#  'indigen',
#  'indigene',
#  'nonworker',
#  'perceiver',
#  'percher',
#  'african-american',
#  'abator',
#  'abjurer',
#  'abstinent',
#  'nondrinker',
#  'succeeder',
#  'acquirer',
#  'adoptee',
#  'resister',
#  'advisee',
#  'advocator',
#  'affiant',
#  'anti-american',
#  'apprehender',
#  'appreciator',
#  'archaist',
#  'arrogator',
#  'assessee',
#  'autodidact',
#  'every',
#  'education',
#  'teaching',
#  'brown',
#  'skills',
#  'actually',
#  'knowing',
#  'same',
#  'generation',
#  'exactly',
#  'only',
#  'ordinary',
#  'given',
#  'fact',
#  'no',
#  'alone',
#  'find',
#  'regardless',
#  'nothing',
#  'finding',
#  'always',
#  'so',
#  'instance',
#  'know',
#  'true',
#  'kind',
#  'otherwise',
#  'if',
#  'bonobo',
#  'neither',
#  'rather',
#  'very',
#  'either',
#  'answer',
#  'an',
#  'merely',
#  'gets',
#  'something',
#  'none',
#  'perhaps',
#  'rarely',
#  'dna',
#  'less',
#  'indeed',
#  'be',
#  'presumably',
#  'simply',
#  'means',
#  'question',
#  'ape',
#  'because',
#  'each',
#  'supposedly',
#  'longer',
#  'takes',
#  'even',
#  'almost',
#  'supposed',
#  'or',
#  'giving',
#  'a',
#  'just',
#  'anything',
#  'without',
#  'blind',
#  'why',
#  'gives',
#  'there',
#  'wrong',
#  'probably',
#  'him',
#  'yet',
#  'normally',
#  'finds',
#  'does',
#  'least',
#  'parents',
#  'is',
#  'but',
#  'usually',
#  'unknown',
#  'sort',
#  'mean',
#  'goes',
#  'evolution',
#  'subfamily',
#  'foreigner',
#  'political',
#  'individuals',
#  'anybody',
#  'citizen',
#  'perpetrator',
#  'fossil',
#  'gentleman',
#  'elector',
#  'homo sapiens idaltu',
#  'tanzania',
#  'spouse',
#  'caller',
#  'citizenship',
#  'participant',
#  'lady',
#  'defendant',
#  'homo sapiens sapiens',
#  'caregiver',
#  'girl',
#  'offender',
#  'salesperson',
#  'claimant',
#  'interviewee',
#  'suspect',
#  'homo sapiens',
#  'servant',
#  'paleontology',
#  'respondent',
#  'personage',
#  'candidate',
#  'shooter',
#  'scientist',
#  'carolus linnaeus',
#  'inmate',
#  'everybody',
#  'complainant',
#  'mensch',
#  'eurasia',
#  'member',
#  'recipient',
#  'addressee',
#  'resident',
#  'personally',
#  'carer',
#  'tenant',
#  'neanderthal',
#  'visitor',
#  'smoker',
#  'prisoner',
#  'daughter',
#  'wearer',
#  'plaintiff',
#  'witness',
#  'deceased',
#  'britain',
#  'passenger',
#  'men',
#  'strangers',
#  'noone',
#  'myself',
#  'taxpayer',
#  'liberty',
#  'who',
#  'holder',
#  'australia',
#  'detainee',
#  'mankind',
#  'nominee',
#  'client',
#  'personal',
#  'beneficiary',
#  'officer',
#  'americas',
#  'petitioner',
#  'officers',
#  'paleolithic',
#  'mesolithic',
#  'neolithic',
#  'nomads',
#  'season',
#  'crops',
#  'farming',
#  'hominin',
#  'rights',
#  'metal',
#  'voice',
#  'country',
#  'egypt',
#  'causal agency',
#  'causal agent',
#  'human body',
#  'material body',
#  'physical body',
#  'unusual person',
#  'color-blind person',
#  'common man',
#  'common person',
#  'applied scientist',
#  'female person',
#  'inexperienced person',
#  'juvenile person',
#  'loved one',
#  'male person',
#  'money dealer',
#  'money handler',
#  'nonreligious person',
#  'primitive person',
#  'religious person',
#  'unfortunate person',
#  'persona non grata',
#  'unwelcome person',
#  'unskilled person',
#  'person of color',
#  'person of colour',
#  'white person',
#  'native american',
#  'water bearer',
#  'india',
#  'syria',
#  'army',
#  'legal obligation',
#  'empire',
#  'slavery',
#  'greece',
#  'registrant',
#  'nominator',
#  'judaism',
#  'transferee',
#  'permittee',
#  'hinduism',
#  'cardholder',
#  'railway',
#  'electricity',
#  'personal identity',
#  'telephone',
#  'abortion',
#  'internet',
#  'pre-history',
#  'water',
#  'nature',
#  'transport',
#  'population',
#  'asia',
#  'africa',
#  'oceania',
#  'town',
#  'city',
#  'predator',
#  'ethnic group',
#  'industry',
#  'animals',
#  'hair',
#  'genitalia',
#  'head',
#  'chest',
#  'common chimpanzee',
#  'red',
#  'blond',
#  'corporations',
#  'grey',
#  'sahelanthropus tchadensis',
#  'skin',
#  'pink',
#  'melanin',
#  'ultraviolet',
#  'sunlight',
#  'great ape',
#  'homo habilis',
#  'polity',
#  'homo erectus',
#  'sahara pump theory',
#  'estate',
#  'east africa',
#  'sleep',
#  'health',
#  'group',
#  'equality before the law',
#  'probate',
#  'baby',
#  'vagina',
#  'bones',
#  'identity',
#  'natural person',
#  'medication',
#  'weight',
#  'kg',
#  'centimetre',
#  'children',
#  'legal personality',
#  'company',
#  'teenager',
#  'neolithic revolution',
#  'human settlement',
#  'monaco',
#  'biology',
#  'mind',
#  'legal liability',
#  'movement',
#  'breathing',
#  'linguistics',
#  'mammals',
#  'persona',
#  'ancient rome',
#  'neurology',
#  'psychology',
#  "women's rights",
#  'writing',
#  'growth',
#  'team',
#  'medicine',
#  'prosopon',
#  'party',
#  'fetal rights',
#  'object',
#  'reading',
#  'organization',
#  'situation',
#  'dog',
#  'persons',
#  'the americas',
#  'christology',
#  'place',
#  'monster',
#  'business',
#  'online',
#  'syntax',
#  'animal rights',
#  'parent',
#  'vocabulary',
#  'bot',
#  'item',
#  'relationship',
#  'hybrid',
#  'the',
#  'vehicle',
#  'other',
#  'kid',
#  'owner',
#  'their',
#  'living',
#  'body',
#  'job',
#  'department',
#  'celebrity',
#  'gamer',
#  'have',
#  'student',
#  'video',
#  'pet',
#  'faction',
#  'account',
#  'cases',
#  'corporation',
#  'some',
#  'poc',
#  'org',
#  'via',
#  'crush',
#  'side',
#  'what',
#  'organisation',
#  'household',
#  'boyfriend',
#  'institution',
#  'event',
#  'cop',
#  'professional',
#  'store',
#  'coach',
#  'ppl',
#  'phone',
#  'you',
#  'past',
#  'time',
#  'partner',
#  'artist',
#  'first',
#  'topic',
#  'deaths',
#  'posse',
#  'united nations',
#  'school',
#  'mentor',
#  'residence',
#  'hiring',
#  'robot',
#  'credible',
#  'computer',
#  'name',
#  'great',
#  'idol',
#  'position',
#  'site',
#  'bad',
#  'love',
#  'committee',
#  'story',
#  'society',
#  'teacher',
#  'these',
#  'multiple',
#  'race',
#  'renter',
#  'rapper',
#  'second',
#  'groups',
#  'streamer',
#  'troll',
#  'website',
#  'poster',
#  'resource',
#  'photo',
#  'writer',
#  'gay',
#  'third',
#  'club',
#  'over',
#  'better',
#  'per',
#  'shop',
#  'interaction',
#  'lawyer',
#  'many',
#  'service',
#  'doctor',
#  'stealth',
#  'more',
#  'mom',
#  'guild',
#  'artefact',
#  'has',
#  'dept',
#  'lifestyle',
#  'sister',
#  'early',
#  'president',
#  'girlfriend',
#  'cockpit',
#  'dangerous',
#  'obesity',
#  'restorer',
#  'snaps',
#  'action',
#  'claudette',
#  'surface',
#  'below',
#  'drink',
#  'studio',
#  'day',
#  'shortcomings',
#  'toxic',
#  'corporate',
#  'bottle',
#  'stand',
#  'program',
#  'serving',
#  'her',
#  'history',
#  'post',
#  'brand',
#  'dead',
#  'hands',
#  'non human',
#  'boethius',
#  'united states',
#  'painting',
#  'sculpture',
#  'photograph',
#  'drums',
#  'violin',
#  'books',
#  'poetry',
#  'legend',
#  'myths',
#  'wikipedia',
#  'gene',
#  'racism',
#  'religion',
#  'belief',
#  'faith',
#  'religious',
#  'god',
#  'atheism',
#  'agnosticism',
#  'universe',
#  'telescope',
#  'galileo',
#  'lasers',
#  'computing',
#  'state',
#  'soldiers',
#  'terrorism',
#  'propaganda',
#  'hiroshima',
#  'nagasaki',
#  'food chain',
#  'neocortex',
#  'climate change',
#  'human height',
#  'artificial intelligences',
#  'extraterrestrial life',
#  'trinitarianism',
#  'sovereign states',
#  'skin cancer',
#  'celeb',
#  'polititian',
#  'mljr',
#  'natural selection',
#  'philosophy of mind',
#  'continental philosophy',
#  'old age',
#  'life expectancy',
#  'analytic philosophy',
#  'bundle theory',
#  'hormone system',
#  'pituitary gland',
#  'ancient greek language',
#  'computer science',
#  'first language',
#  'mandarin chinese',
#  'second language',
#  'romanization of ancient greek',
#  'theatre of ancient greece',
#  'john locke',
#  'immanuel kant',
#  'lynne baker',
#  'musical instrument',
#  'electric guitar',
#  'keyboard instrument',
#  'fairy tale',
#  'creation myth',
#  'albert einstein',
#  'theory of relativity',
#  'guerrilla warfare',
#  'nuclear bomb',
#  'world war ii',
#  'acute radiation syndrome',
#  'animal',
#  'dog',
#  'cat',
#  'bird',
#  'puppy',
#  'favorite',
#  'favourite',
#  'darling',
#  'favored',
#  'rottweiler',
#  'loved',
#  'fondle',
#  'caress',
#  'rabbit',
#  'eat',
#  'preferred',
#  'dearie',
#  'deary',
#  'ducky',
#  'rodent',
#  'turtle',
#  'positron emission tomography',
#  'goldfish',
#  'livestock',
#  'kennel',
#  'greyhound',
#  'hamster',
#  'beagle',
#  'spaniel',
#  'poodle',
#  'corgi',
#  'foxhound',
#  'doggie',
#  'pomeranian',
#  'elephant',
#  'dachshund',
#  'collie',
#  'pup',
#  'schipperke',
#  'schnauzer',
#  'yorkie',
#  'animal-assisted therapy',
#  'miniature pinscher',
#  'fox terrier',
#  'golden retriever',
#  'irish setter',
#  'shetland sheepdog',
#  'basset hound',
#  'shih tzu',
#  'lhasa apso',
#  'labrador retriever',
#  'cocker spaniel',
#  'airedale terrier',
#  'french bulldog',
#  'great dane',
#  'guinea pig',
#  'rat',
#  'monkey',
#  'mouse',
#  'kitten',
#  'veterinarian',
#  'pug',
#  'domestication',
#  'preferent',
#  'best-loved',
#  'labour',
#  'peevishness',
#  'irritability',
#  'neck',
#  'chosen',
#  'choler',
#  'lover',
#  'fauna',
#  'gentle',
#  'creature',
#  'petulance',
#  'beast',
#  'fretfulness',
#  'tomography',
#  'imaging',
#  'brute',
#  'purebred',
#  'ferret',
#  'fido',
#  'gerbil',
#  'rex',
#  'chinchilla',
#  'deerhound',
#  'canis',
#  'griffon',
#  'sheepdog',
#  'doggedly',
#  'doggedness',
#  'whippet',
#  'dogger',
#  'lurcher',
#  'doggy',
#  'retriever',
#  'cur',
#  'pertinaciously',
#  'akita',
#  'doghouse',
#  'flea',
#  'dingo',
#  'bloodhound',
#  'macushla',
#  'fussiness',
#  'mollycoddle',
#  'canoodle',
#  'crossness',
#  'canine',
#  'dogcart',
#  'spitz',
#  'antidog',
#  'pulegone',
#  'pets',
#  'hemangiosarcoma',
#  'parakeet',
#  'parrot',
#  'multidog',
#  'cefovecin',
#  'furkid',
#  'ratter',
#  'fish',
#  'lizard',
#  'baby',
#  'dognap',
#  'snake',
#  'demiwolf',
#  'harehound',
#  'dogling',
#  'dognapping',
#  'dogsitter',
#  'trundletail',
#  'dogdom',
#  'aquarium',
#  'coonhound',
#  'dogophile',
#  'crocotta',
#  'robodog',
#  'dhole',
#  'dogbane',
#  'lapdog',
#  'basenji',
#  'dogberryism',
#  'doglore',
#  'cyno',
#  'dogless',
#  'coondog',
#  'canid',
#  'granddog',
#  'corndog',
#  'lucern',
#  'rottie',
#  'briard',
#  'sleuthhound',
#  'elkhound',
#  'doggishly',
#  'adamance',
#  'coydog',
#  'seadog',
#  'doggily',
#  'doghood',
#  'doggishness',
#  'dogs',
#  'doggish',
#  'labradoodle',
#  'saluki',
#  'dogly',
#  'poochie',
#  'spurdog',
#  'staghound',
#  'pig',
#  'doglike',
#  'otterhound',
#  'bandog',
#  'dogcatcher',
#  'yorkipoo',
#  'coachdog',
#  'leamer',
#  'toys',
#  'weredog',
#  'cow',
#  'cats',
#  'drever',
#  'cynophilia',
#  'utonagan',
#  'samoyed',
#  'cynanthropy',
#  'frog',
#  'eating',
#  'working animal',
#  'bug',
#  'toy',
#  'babies',
#  'animals',
#  'arthropod',
#  'sport animal',
#  'candy',
#  'pigs',
#  'tarantula',
#  'treats',
#  'food',
#  'cloned',
#  'laboratory animal',
#  'rats',
#  ...]

# %%
import pandas as pd
import numpy as np

# %%
topic_modeling_df = pd.read_csv("./topic_modeling.csv").to_numpy()
topic_modeling_df
# Out:
# array([[0, 'algorithm', 'Computer Science'],
#        [1, 'mathematics', 'Computer Science'],
#        [2, 'computer engineering', 'Computer Science'],
#        ...,
#        [270499, 'notitiae episcopatuum', 'Physics'],
#        [270500, 'lampsacus treasure', 'Physics'],
#        [270501, 'titular see', 'Physics']], dtype=object)

# %%
for i in range(len(person_word)):
    person_word[i] = np.array([270501 + i + 1, person_word[i], "Person"])
person_word
# Out:
# [array(['270502', 'people', 'Person'], dtype='<U11'),
#  array(['270503', 'someone', 'Person'], dtype='<U11'),
#  array(['270504', 'child', 'Person'], dtype='<U11'),
#  array(['270505', 'adult', 'Person'], dtype='<U11'),
#  array(['270506', 'worker', 'Person'], dtype='<U11'),
#  array(['270507', 'individual', 'Person'], dtype='<U11'),
#  array(['270508', 'reason', 'Person'], dtype='<U11'),
#  array(['270509', 'personality', 'Person'], dtype='<U11'),
#  array(['270510', 'subject', 'Person'], dtype='<U11'),
#  array(['270511', 'philosophy', 'Person'], dtype='<U11'),
#  array(['270512', 'anyone', 'Person'], dtype='<U11'),
#  array(['270513', 'man', 'Person'], dtype='<U11'),
#  array(['270514', 'woman', 'Person'], dtype='<U11'),
#  array(['270515', 'one', 'Person'], dtype='<U11'),
#  array(['270516', 'patient', 'Person'], dtype='<U11'),
#  array(['270517', 'victim', 'Person'], dtype='<U11'),
#  array(['270518', 'language', 'Person'], dtype='<U11'),
#  array(['270519', 'female', 'Person'], dtype='<U11'),
#  array(['270520', 'mammal', 'Person'], dtype='<U11'),
#  array(['270521', 'primate', 'Person'], dtype='<U11'),
#  array(['270522', 'somebody', 'Person'], dtype='<U11'),
#  array(['270523', 'soul', 'Person'], dtype='<U11'),
#  array(['270524', 'mortal', 'Person'], dtype='<U11'),
#  array(['270525', 'chimpanzee', 'Person'], dtype='<U11'),
#  array(['270526', 'orangutan', 'Person'], dtype='<U11'),
#  array(['270527', 'brain', 'Person'], dtype='<U11'),
#  array(['270528', 'native', 'Person'], dtype='<U11'),
#  array(['270529', 'self', 'Person'], dtype='<U11'),
#  array(['270530', 'applicant', 'Person'], dtype='<U11'),
#  array(['270531', 'inhabitant', 'Person'], dtype='<U11'),
#  array(['270532', 'animal', 'Person'], dtype='<U11'),
#  array(['270533', 'appointee', 'Person'], dtype='<U11'),
#  array(['270534', 'else', 'Person'], dtype='<U11'),
#  array(['270535', 'everyone', 'Person'], dtype='<U11'),
#  array(['270536', 'thing', 'Person'], dtype='<U11'),
#  array(['270537', 'nobody', 'Person'], dtype='<U11'),
#  array(['270538', 'she', 'Person'], dtype='<U11'),
#  array(['270539', 'morality', 'Person'], dtype='<U11'),
#  array(['270540', 'face', 'Person'], dtype='<U11'),
#  array(['270541', 'black', 'Person'], dtype='<U11'),
#  array(['270542', 'white', 'Person'], dtype='<U11'),
#  array(['270543', 'gorilla', 'Person'], dtype='<U11'),
#  array(['270544', 'property', 'Person'], dtype='<U11'),
#  array(['270545', 'being', 'Person'], dtype='<U11'),
#  array(['270546', 'leader', 'Person'], dtype='<U11'),
#  array(['270547', 'friend', 'Person'], dtype='<U11'),
#  array(['270548', 'legs', 'Person'], dtype='<U11'),
#  array(['270549', 'family', 'Person'], dtype='<U11'),
#  array(['270550', 'idea', 'Person'], dtype='<U11'),
#  array(['270551', 'emotion', 'Person'], dtype='<U11'),
#  array(['270552', 'community', 'Person'], dtype='<U11'),
#  array(['270553', 'human', 'Person'], dtype='<U11'),
#  array(['270554', 'pelvis', 'Person'], dtype='<U11'),
#  array(['270555', 'another', 'Person'], dtype='<U11'),
#  array(['270556', 'customs', 'Person'], dtype='<U11'),
#  array(['270557', 'life', 'Person'], dtype='<U11'),
#  array(['270558', 'thought', 'Person'], dtype='<U11'),
#  array(['270559', 'not', 'Person'], dtype='<U11'),
#  array(['270560', 'any', 'Person'], dtype='<U11'),
#  array(['270561', 'how', 'Person'], dtype='<U11'),
#  array(['270562', 'couple', 'Person'], dtype='<U11'),
#  array(['270563', 'having', 'Person'], dtype='<U11'),
#  array(['270564', 'good', 'Person'], dtype='<U11'),
#  array(['270565', 'art', 'Person'], dtype='<U11'),
#  array(['270566', 'literature', 'Person'], dtype='<U11'),
#  array(['270567', 'guy', 'Person'], dtype='<U11'),
#  array(['270568', 'music', 'Person'], dtype='<U11'),
#  array(['270569', 'organism', 'Person'], dtype='<U11'),
#  array(['270570', 'employee', 'Person'], dtype='<U11'),
#  array(['270571', 'creature', 'Person'], dtype='<U11'),
#  array(['270572', 'user', 'Person'], dtype='<U11'),
#  array(['270573', 'entity', 'Person'], dtype='<U11'),
#  array(['270574', 'player', 'Person'], dtype='<U11'),
#  array(['270575', 'type', 'Person'], dtype='<U11'),
#  array(['270576', 'those', 'Person'], dtype='<U11'),
#  array(['270577', 'law', 'Person'], dtype='<U11'),
#  array(['270578', 'character', 'Person'], dtype='<U11'),
#  array(['270579', 'customer', 'Person'], dtype='<U11'),
#  array(['270580', 'genetics', 'Person'], dtype='<U11'),
#  array(['270581', 'hominid', 'Person'], dtype='<U11'),
#  array(['270582', 'chad', 'Person'], dtype='<U11'),
#  array(['270583', 'car', 'Person'], dtype='<U11'),
#  array(['270584', 'europe', 'Person'], dtype='<U11'),
#  array(['270585', 'hunter-gatherer', 'Person'], dtype='<U15'),
#  array(['270586', 'war', 'Person'], dtype='<U11'),
#  array(['270587', 'death', 'Person'], dtype='<U11'),
#  array(['270588', 'extinct', 'Person'], dtype='<U11'),
#  array(['270589', 'species', 'Person'], dtype='<U11'),
#  array(['270590', 'latin', 'Person'], dtype='<U11'),
#  array(['270591', 'order', 'Person'], dtype='<U11'),
#  array(['270592', 'consciousness', 'Person'], dtype='<U13'),
#  array(['270593', 'mother', 'Person'], dtype='<U11'),
#  array(['270594', 'bipedal', 'Person'], dtype='<U11'),
#  array(['270595', 'month', 'Person'], dtype='<U11'),
#  array(['270596', 'kinship', 'Person'], dtype='<U11'),
#  array(['270597', 'arm', 'Person'], dtype='<U11'),
#  array(['270598', 'ownership', 'Person'], dtype='<U11'),
#  array(['270599', 'walking', 'Person'], dtype='<U11'),
#  array(['270600', 'tool', 'Person'], dtype='<U11'),
#  array(['270601', 'continent', 'Person'], dtype='<U11'),
#  array(['270602', 'million', 'Person'], dtype='<U11'),
#  array(['270603', 'earth', 'Person'], dtype='<U11'),
#  array(['270604', 'instinct', 'Person'], dtype='<U11'),
#  array(['270605', 'cause', 'Person'], dtype='<U11'),
#  array(['270606', 'anatomy', 'Person'], dtype='<U11'),
#  array(['270607', 'bod', 'Person'], dtype='<U11'),
#  array(['270608', 'build', 'Person'], dtype='<U11'),
#  array(['270609', 'chassis', 'Person'], dtype='<U11'),
#  array(['270610', 'figure', 'Person'], dtype='<U11'),
#  array(['270611', 'flesh', 'Person'], dtype='<U11'),
#  array(['270612', 'form', 'Person'], dtype='<U11'),
#  array(['270613', 'frame', 'Person'], dtype='<U11'),
#  array(['270614', 'physique', 'Person'], dtype='<U11'),
#  array(['270615', 'shape', 'Person'], dtype='<U11'),
#  array(['270616', 'soma', 'Person'], dtype='<U11'),
#  array(['270617', 'adventurer', 'Person'], dtype='<U11'),
#  array(['270618', 'anomaly', 'Person'], dtype='<U11'),
#  array(['270619', 'anachronism', 'Person'], dtype='<U11'),
#  array(['270620', 'appointment', 'Person'], dtype='<U11'),
#  array(['270621', 'capitalist', 'Person'], dtype='<U11'),
#  array(['270622', 'captor', 'Person'], dtype='<U11'),
#  array(['270623', 'changer', 'Person'], dtype='<U11'),
#  array(['270624', 'modifier', 'Person'], dtype='<U11'),
#  array(['270625', 'commoner', 'Person'], dtype='<U11'),
#  array(['270626', 'communicator', 'Person'], dtype='<U12'),
#  array(['270627', 'contestant', 'Person'], dtype='<U11'),
#  array(['270628', 'coward', 'Person'], dtype='<U11'),
#  array(['270629', 'creator', 'Person'], dtype='<U11'),
#  array(['270630', 'controversialist', 'Person'], dtype='<U16'),
#  array(['270631', 'disputant', 'Person'], dtype='<U11'),
#  array(['270632', 'engineer', 'Person'], dtype='<U11'),
#  array(['270633', 'technologist', 'Person'], dtype='<U12'),
#  array(['270634', 'entertainer', 'Person'], dtype='<U11'),
#  array(['270635', 'experimenter', 'Person'], dtype='<U12'),
#  array(['270636', 'expert', 'Person'], dtype='<U11'),
#  array(['270637', 'individualist', 'Person'], dtype='<U13'),
#  array(['270638', 'denizen', 'Person'], dtype='<U11'),
#  array(['270639', 'dweller', 'Person'], dtype='<U11'),
#  array(['270640', 'habitant', 'Person'], dtype='<U11'),
#  array(['270641', 'aboriginal', 'Person'], dtype='<U11'),
#  array(['270642', 'aborigine', 'Person'], dtype='<U11'),
#  array(['270643', 'innocent', 'Person'], dtype='<U11'),
#  array(['270644', 'intellect', 'Person'], dtype='<U11'),
#  array(['270645', 'intellectual', 'Person'], dtype='<U12'),
#  array(['270646', 'juvenile', 'Person'], dtype='<U11'),
#  array(['270647', 'lover', 'Person'], dtype='<U11'),
#  array(['270648', 'male', 'Person'], dtype='<U11'),
#  array(['270649', 'national', 'Person'], dtype='<U11'),
#  array(['270650', 'compeer', 'Person'], dtype='<U11'),
#  array(['270651', 'equal', 'Person'], dtype='<U11'),
#  array(['270652', 'match', 'Person'], dtype='<U11'),
#  array(['270653', 'peer', 'Person'], dtype='<U11'),
#  array(['270654', 'beholder', 'Person'], dtype='<U11'),
#  array(['270655', 'observer', 'Person'], dtype='<U11'),
#  array(['270656', 'percipient', 'Person'], dtype='<U11'),
#  array(['270657', 'forerunner', 'Person'], dtype='<U11'),
#  array(['270658', 'precursor', 'Person'], dtype='<U11'),
#  array(['270659', 'primitive', 'Person'], dtype='<U11'),
#  array(['270660', 'sensualist', 'Person'], dtype='<U11'),
#  array(['270661', 'traveler', 'Person'], dtype='<U11'),
#  array(['270662', 'traveller', 'Person'], dtype='<U11'),
#  array(['270663', 'unfortunate', 'Person'], dtype='<U11'),
#  array(['270664', 'african', 'Person'], dtype='<U11'),
#  array(['270665', 'caucasian', 'Person'], dtype='<U11'),
#  array(['270666', 'amerindian', 'Person'], dtype='<U11'),
#  array(['270667', 'slav', 'Person'], dtype='<U11'),
#  array(['270668', 'gentile', 'Person'], dtype='<U11'),
#  array(['270669', 'hebrew', 'Person'], dtype='<U11'),
#  array(['270670', 'israelite', 'Person'], dtype='<U11'),
#  array(['270671', 'aries', 'Person'], dtype='<U11'),
#  array(['270672', 'ram', 'Person'], dtype='<U11'),
#  array(['270673', 'bull', 'Person'], dtype='<U11'),
#  array(['270674', 'taurus', 'Person'], dtype='<U11'),
#  array(['270675', 'gemini', 'Person'], dtype='<U11'),
#  array(['270676', 'twin', 'Person'], dtype='<U11'),
#  array(['270677', 'cancer', 'Person'], dtype='<U11'),
#  array(['270678', 'crab', 'Person'], dtype='<U11'),
#  array(['270679', 'leo', 'Person'], dtype='<U11'),
#  array(['270680', 'lion', 'Person'], dtype='<U11'),
#  array(['270681', 'virgin', 'Person'], dtype='<U11'),
#  array(['270682', 'virgo', 'Person'], dtype='<U11'),
#  array(['270683', 'balance', 'Person'], dtype='<U11'),
#  array(['270684', 'libra', 'Person'], dtype='<U11'),
#  array(['270685', 'scorpio', 'Person'], dtype='<U11'),
#  array(['270686', 'scorpion', 'Person'], dtype='<U11'),
#  array(['270687', 'archer', 'Person'], dtype='<U11'),
#  array(['270688', 'sagittarius', 'Person'], dtype='<U11'),
#  array(['270689', 'capricorn', 'Person'], dtype='<U11'),
#  array(['270690', 'goat', 'Person'], dtype='<U11'),
#  array(['270691', 'aquarius', 'Person'], dtype='<U11'),
#  array(['270692', 'fish', 'Person'], dtype='<U11'),
#  array(['270693', 'pisces', 'Person'], dtype='<U11'),
#  array(['270694', 'abomination', 'Person'], dtype='<U11'),
#  array(['270695', 'abstainer', 'Person'], dtype='<U11'),
#  array(['270696', 'achiever', 'Person'], dtype='<U11'),
#  array(['270697', 'success', 'Person'], dtype='<U11'),
#  array(['270698', 'winner', 'Person'], dtype='<U11'),
#  array(['270699', 'acquaintance', 'Person'], dtype='<U12'),
#  array(['270700', 'active', 'Person'], dtype='<U11'),
#  array(['270701', 'actor', 'Person'], dtype='<U11'),
#  array(['270702', 'doer', 'Person'], dtype='<U11'),
#  array(['270703', 'adjudicator', 'Person'], dtype='<U11'),
#  array(['270704', 'admirer', 'Person'], dtype='<U11'),
#  array(['270705', 'adversary', 'Person'], dtype='<U11'),
#  array(['270706', 'antagonist', 'Person'], dtype='<U11'),
#  array(['270707', 'opponent', 'Person'], dtype='<U11'),
#  array(['270708', 'opposer', 'Person'], dtype='<U11'),
#  array(['270709', 'advocate', 'Person'], dtype='<U11'),
#  array(['270710', 'exponent', 'Person'], dtype='<U11'),
#  array(['270711', 'proponent', 'Person'], dtype='<U11'),
#  array(['270712', 'agnostic', 'Person'], dtype='<U11'),
#  array(['270713', 'doubter', 'Person'], dtype='<U11'),
#  array(['270714', 'albino', 'Person'], dtype='<U11'),
#  array(['270715', 'amateur', 'Person'], dtype='<U11'),
#  array(['270716', 'ancient', 'Person'], dtype='<U11'),
#  array(['270717', 'anti', 'Person'], dtype='<U11'),
#  array(['270718', 'asthmatic', 'Person'], dtype='<U11'),
#  array(['270719', 'authority', 'Person'], dtype='<U11'),
#  array(['270720', 'automaton', 'Person'], dtype='<U11'),
#  array(['270721', 'learning', 'Person'], dtype='<U11'),
#  array(['270722', 'childhood', 'Person'], dtype='<U11'),
#  array(['270723', 'birth', 'Person'], dtype='<U11'),
#  array(['270724', 'personhood', 'Person'], dtype='<U11'),
#  array(['270725', 'sign', 'Person'], dtype='<U11'),
#  array(['270726', 'abstraction', 'Person'], dtype='<U11'),
#  array(['270727', 'hominidae', 'Person'], dtype='<U11'),
#  array(['270728', 'communication', 'Person'], dtype='<U13'),
#  array(['270729', 'laws', 'Person'], dtype='<U11'),
#  array(['270730', 'self-consciousness', 'Person'], dtype='<U18'),
#  array(['270731', 'tradition', 'Person'], dtype='<U11'),
#  array(['270732', 'world', 'Person'], dtype='<U11'),
#  array(['270733', 'myth', 'Person'], dtype='<U11'),
#  array(['270734', 'science', 'Person'], dtype='<U11'),
#  array(['270735', 'fire', 'Person'], dtype='<U11'),
#  array(['270736', 'cooking', 'Person'], dtype='<U11'),
#  array(['270737', 'food', 'Person'], dtype='<U11'),
#  array(['270738', 'clothes', 'Person'], dtype='<U11'),
#  array(['270739', 'technology', 'Person'], dtype='<U11'),
#  array(['270740', 'beauty', 'Person'], dtype='<U11'),
#  array(['270741', 'nation', 'Person'], dtype='<U11'),
#  array(['270742', 'grownup', 'Person'], dtype='<U11'),
#  array(['270743', 'venturer', 'Person'], dtype='<U11'),
#  array(['270744', 'applier', 'Person'], dtype='<U11'),
#  array(['270745', 'capturer', 'Person'], dtype='<U11'),
#  array(['270746', 'eristic', 'Person'], dtype='<U11'),
#  array(['270747', 'indweller', 'Person'], dtype='<U11'),
#  array(['270748', 'indigen', 'Person'], dtype='<U11'),
#  array(['270749', 'indigene', 'Person'], dtype='<U11'),
#  array(['270750', 'nonworker', 'Person'], dtype='<U11'),
#  array(['270751', 'perceiver', 'Person'], dtype='<U11'),
#  array(['270752', 'percher', 'Person'], dtype='<U11'),
#  array(['270753', 'african-american', 'Person'], dtype='<U16'),
#  array(['270754', 'abator', 'Person'], dtype='<U11'),
#  array(['270755', 'abjurer', 'Person'], dtype='<U11'),
#  array(['270756', 'abstinent', 'Person'], dtype='<U11'),
#  array(['270757', 'nondrinker', 'Person'], dtype='<U11'),
#  array(['270758', 'succeeder', 'Person'], dtype='<U11'),
#  array(['270759', 'acquirer', 'Person'], dtype='<U11'),
#  array(['270760', 'adoptee', 'Person'], dtype='<U11'),
#  array(['270761', 'resister', 'Person'], dtype='<U11'),
#  array(['270762', 'advisee', 'Person'], dtype='<U11'),
#  array(['270763', 'advocator', 'Person'], dtype='<U11'),
#  array(['270764', 'affiant', 'Person'], dtype='<U11'),
#  array(['270765', 'anti-american', 'Person'], dtype='<U13'),
#  array(['270766', 'apprehender', 'Person'], dtype='<U11'),
#  array(['270767', 'appreciator', 'Person'], dtype='<U11'),
#  array(['270768', 'archaist', 'Person'], dtype='<U11'),
#  array(['270769', 'arrogator', 'Person'], dtype='<U11'),
#  array(['270770', 'assessee', 'Person'], dtype='<U11'),
#  array(['270771', 'autodidact', 'Person'], dtype='<U11'),
#  array(['270772', 'every', 'Person'], dtype='<U11'),
#  array(['270773', 'education', 'Person'], dtype='<U11'),
#  array(['270774', 'teaching', 'Person'], dtype='<U11'),
#  array(['270775', 'brown', 'Person'], dtype='<U11'),
#  array(['270776', 'skills', 'Person'], dtype='<U11'),
#  array(['270777', 'actually', 'Person'], dtype='<U11'),
#  array(['270778', 'knowing', 'Person'], dtype='<U11'),
#  array(['270779', 'same', 'Person'], dtype='<U11'),
#  array(['270780', 'generation', 'Person'], dtype='<U11'),
#  array(['270781', 'exactly', 'Person'], dtype='<U11'),
#  array(['270782', 'only', 'Person'], dtype='<U11'),
#  array(['270783', 'ordinary', 'Person'], dtype='<U11'),
#  array(['270784', 'given', 'Person'], dtype='<U11'),
#  array(['270785', 'fact', 'Person'], dtype='<U11'),
#  array(['270786', 'no', 'Person'], dtype='<U11'),
#  array(['270787', 'alone', 'Person'], dtype='<U11'),
#  array(['270788', 'find', 'Person'], dtype='<U11'),
#  array(['270789', 'regardless', 'Person'], dtype='<U11'),
#  array(['270790', 'nothing', 'Person'], dtype='<U11'),
#  array(['270791', 'finding', 'Person'], dtype='<U11'),
#  array(['270792', 'always', 'Person'], dtype='<U11'),
#  array(['270793', 'so', 'Person'], dtype='<U11'),
#  array(['270794', 'instance', 'Person'], dtype='<U11'),
#  array(['270795', 'know', 'Person'], dtype='<U11'),
#  array(['270796', 'true', 'Person'], dtype='<U11'),
#  array(['270797', 'kind', 'Person'], dtype='<U11'),
#  array(['270798', 'otherwise', 'Person'], dtype='<U11'),
#  array(['270799', 'if', 'Person'], dtype='<U11'),
#  array(['270800', 'bonobo', 'Person'], dtype='<U11'),
#  array(['270801', 'neither', 'Person'], dtype='<U11'),
#  array(['270802', 'rather', 'Person'], dtype='<U11'),
#  array(['270803', 'very', 'Person'], dtype='<U11'),
#  array(['270804', 'either', 'Person'], dtype='<U11'),
#  array(['270805', 'answer', 'Person'], dtype='<U11'),
#  array(['270806', 'an', 'Person'], dtype='<U11'),
#  array(['270807', 'merely', 'Person'], dtype='<U11'),
#  array(['270808', 'gets', 'Person'], dtype='<U11'),
#  array(['270809', 'something', 'Person'], dtype='<U11'),
#  array(['270810', 'none', 'Person'], dtype='<U11'),
#  array(['270811', 'perhaps', 'Person'], dtype='<U11'),
#  array(['270812', 'rarely', 'Person'], dtype='<U11'),
#  array(['270813', 'dna', 'Person'], dtype='<U11'),
#  array(['270814', 'less', 'Person'], dtype='<U11'),
#  array(['270815', 'indeed', 'Person'], dtype='<U11'),
#  array(['270816', 'be', 'Person'], dtype='<U11'),
#  array(['270817', 'presumably', 'Person'], dtype='<U11'),
#  array(['270818', 'simply', 'Person'], dtype='<U11'),
#  array(['270819', 'means', 'Person'], dtype='<U11'),
#  array(['270820', 'question', 'Person'], dtype='<U11'),
#  array(['270821', 'ape', 'Person'], dtype='<U11'),
#  array(['270822', 'because', 'Person'], dtype='<U11'),
#  array(['270823', 'each', 'Person'], dtype='<U11'),
#  array(['270824', 'supposedly', 'Person'], dtype='<U11'),
#  array(['270825', 'longer', 'Person'], dtype='<U11'),
#  array(['270826', 'takes', 'Person'], dtype='<U11'),
#  array(['270827', 'even', 'Person'], dtype='<U11'),
#  array(['270828', 'almost', 'Person'], dtype='<U11'),
#  array(['270829', 'supposed', 'Person'], dtype='<U11'),
#  array(['270830', 'or', 'Person'], dtype='<U11'),
#  array(['270831', 'giving', 'Person'], dtype='<U11'),
#  array(['270832', 'a', 'Person'], dtype='<U11'),
#  array(['270833', 'just', 'Person'], dtype='<U11'),
#  array(['270834', 'anything', 'Person'], dtype='<U11'),
#  array(['270835', 'without', 'Person'], dtype='<U11'),
#  array(['270836', 'blind', 'Person'], dtype='<U11'),
#  array(['270837', 'why', 'Person'], dtype='<U11'),
#  array(['270838', 'gives', 'Person'], dtype='<U11'),
#  array(['270839', 'there', 'Person'], dtype='<U11'),
#  array(['270840', 'wrong', 'Person'], dtype='<U11'),
#  array(['270841', 'probably', 'Person'], dtype='<U11'),
#  array(['270842', 'him', 'Person'], dtype='<U11'),
#  array(['270843', 'yet', 'Person'], dtype='<U11'),
#  array(['270844', 'normally', 'Person'], dtype='<U11'),
#  array(['270845', 'finds', 'Person'], dtype='<U11'),
#  array(['270846', 'does', 'Person'], dtype='<U11'),
#  array(['270847', 'least', 'Person'], dtype='<U11'),
#  array(['270848', 'parents', 'Person'], dtype='<U11'),
#  array(['270849', 'is', 'Person'], dtype='<U11'),
#  array(['270850', 'but', 'Person'], dtype='<U11'),
#  array(['270851', 'usually', 'Person'], dtype='<U11'),
#  array(['270852', 'unknown', 'Person'], dtype='<U11'),
#  array(['270853', 'sort', 'Person'], dtype='<U11'),
#  array(['270854', 'mean', 'Person'], dtype='<U11'),
#  array(['270855', 'goes', 'Person'], dtype='<U11'),
#  array(['270856', 'evolution', 'Person'], dtype='<U11'),
#  array(['270857', 'subfamily', 'Person'], dtype='<U11'),
#  array(['270858', 'foreigner', 'Person'], dtype='<U11'),
#  array(['270859', 'political', 'Person'], dtype='<U11'),
#  array(['270860', 'individuals', 'Person'], dtype='<U11'),
#  array(['270861', 'anybody', 'Person'], dtype='<U11'),
#  array(['270862', 'citizen', 'Person'], dtype='<U11'),
#  array(['270863', 'perpetrator', 'Person'], dtype='<U11'),
#  array(['270864', 'fossil', 'Person'], dtype='<U11'),
#  array(['270865', 'gentleman', 'Person'], dtype='<U11'),
#  array(['270866', 'elector', 'Person'], dtype='<U11'),
#  array(['270867', 'homo sapiens idaltu', 'Person'], dtype='<U19'),
#  array(['270868', 'tanzania', 'Person'], dtype='<U11'),
#  array(['270869', 'spouse', 'Person'], dtype='<U11'),
#  array(['270870', 'caller', 'Person'], dtype='<U11'),
#  array(['270871', 'citizenship', 'Person'], dtype='<U11'),
#  array(['270872', 'participant', 'Person'], dtype='<U11'),
#  array(['270873', 'lady', 'Person'], dtype='<U11'),
#  array(['270874', 'defendant', 'Person'], dtype='<U11'),
#  array(['270875', 'homo sapiens sapiens', 'Person'], dtype='<U20'),
#  array(['270876', 'caregiver', 'Person'], dtype='<U11'),
#  array(['270877', 'girl', 'Person'], dtype='<U11'),
#  array(['270878', 'offender', 'Person'], dtype='<U11'),
#  array(['270879', 'salesperson', 'Person'], dtype='<U11'),
#  array(['270880', 'claimant', 'Person'], dtype='<U11'),
#  array(['270881', 'interviewee', 'Person'], dtype='<U11'),
#  array(['270882', 'suspect', 'Person'], dtype='<U11'),
#  array(['270883', 'homo sapiens', 'Person'], dtype='<U12'),
#  array(['270884', 'servant', 'Person'], dtype='<U11'),
#  array(['270885', 'paleontology', 'Person'], dtype='<U12'),
#  array(['270886', 'respondent', 'Person'], dtype='<U11'),
#  array(['270887', 'personage', 'Person'], dtype='<U11'),
#  array(['270888', 'candidate', 'Person'], dtype='<U11'),
#  array(['270889', 'shooter', 'Person'], dtype='<U11'),
#  array(['270890', 'scientist', 'Person'], dtype='<U11'),
#  array(['270891', 'carolus linnaeus', 'Person'], dtype='<U16'),
#  array(['270892', 'inmate', 'Person'], dtype='<U11'),
#  array(['270893', 'everybody', 'Person'], dtype='<U11'),
#  array(['270894', 'complainant', 'Person'], dtype='<U11'),
#  array(['270895', 'mensch', 'Person'], dtype='<U11'),
#  array(['270896', 'eurasia', 'Person'], dtype='<U11'),
#  array(['270897', 'member', 'Person'], dtype='<U11'),
#  array(['270898', 'recipient', 'Person'], dtype='<U11'),
#  array(['270899', 'addressee', 'Person'], dtype='<U11'),
#  array(['270900', 'resident', 'Person'], dtype='<U11'),
#  array(['270901', 'personally', 'Person'], dtype='<U11'),
#  array(['270902', 'carer', 'Person'], dtype='<U11'),
#  array(['270903', 'tenant', 'Person'], dtype='<U11'),
#  array(['270904', 'neanderthal', 'Person'], dtype='<U11'),
#  array(['270905', 'visitor', 'Person'], dtype='<U11'),
#  array(['270906', 'smoker', 'Person'], dtype='<U11'),
#  array(['270907', 'prisoner', 'Person'], dtype='<U11'),
#  array(['270908', 'daughter', 'Person'], dtype='<U11'),
#  array(['270909', 'wearer', 'Person'], dtype='<U11'),
#  array(['270910', 'plaintiff', 'Person'], dtype='<U11'),
#  array(['270911', 'witness', 'Person'], dtype='<U11'),
#  array(['270912', 'deceased', 'Person'], dtype='<U11'),
#  array(['270913', 'britain', 'Person'], dtype='<U11'),
#  array(['270914', 'passenger', 'Person'], dtype='<U11'),
#  array(['270915', 'men', 'Person'], dtype='<U11'),
#  array(['270916', 'strangers', 'Person'], dtype='<U11'),
#  array(['270917', 'noone', 'Person'], dtype='<U11'),
#  array(['270918', 'myself', 'Person'], dtype='<U11'),
#  array(['270919', 'taxpayer', 'Person'], dtype='<U11'),
#  array(['270920', 'liberty', 'Person'], dtype='<U11'),
#  array(['270921', 'who', 'Person'], dtype='<U11'),
#  array(['270922', 'holder', 'Person'], dtype='<U11'),
#  array(['270923', 'australia', 'Person'], dtype='<U11'),
#  array(['270924', 'detainee', 'Person'], dtype='<U11'),
#  array(['270925', 'mankind', 'Person'], dtype='<U11'),
#  array(['270926', 'nominee', 'Person'], dtype='<U11'),
#  array(['270927', 'client', 'Person'], dtype='<U11'),
#  array(['270928', 'personal', 'Person'], dtype='<U11'),
#  array(['270929', 'beneficiary', 'Person'], dtype='<U11'),
#  array(['270930', 'officer', 'Person'], dtype='<U11'),
#  array(['270931', 'americas', 'Person'], dtype='<U11'),
#  array(['270932', 'petitioner', 'Person'], dtype='<U11'),
#  array(['270933', 'officers', 'Person'], dtype='<U11'),
#  array(['270934', 'paleolithic', 'Person'], dtype='<U11'),
#  array(['270935', 'mesolithic', 'Person'], dtype='<U11'),
#  array(['270936', 'neolithic', 'Person'], dtype='<U11'),
#  array(['270937', 'nomads', 'Person'], dtype='<U11'),
#  array(['270938', 'season', 'Person'], dtype='<U11'),
#  array(['270939', 'crops', 'Person'], dtype='<U11'),
#  array(['270940', 'farming', 'Person'], dtype='<U11'),
#  array(['270941', 'hominin', 'Person'], dtype='<U11'),
#  array(['270942', 'rights', 'Person'], dtype='<U11'),
#  array(['270943', 'metal', 'Person'], dtype='<U11'),
#  array(['270944', 'voice', 'Person'], dtype='<U11'),
#  array(['270945', 'country', 'Person'], dtype='<U11'),
#  array(['270946', 'egypt', 'Person'], dtype='<U11'),
#  array(['270947', 'causal agency', 'Person'], dtype='<U13'),
#  array(['270948', 'causal agent', 'Person'], dtype='<U12'),
#  array(['270949', 'human body', 'Person'], dtype='<U11'),
#  array(['270950', 'material body', 'Person'], dtype='<U13'),
#  array(['270951', 'physical body', 'Person'], dtype='<U13'),
#  array(['270952', 'unusual person', 'Person'], dtype='<U14'),
#  array(['270953', 'color-blind person', 'Person'], dtype='<U18'),
#  array(['270954', 'common man', 'Person'], dtype='<U11'),
#  array(['270955', 'common person', 'Person'], dtype='<U13'),
#  array(['270956', 'applied scientist', 'Person'], dtype='<U17'),
#  array(['270957', 'female person', 'Person'], dtype='<U13'),
#  array(['270958', 'inexperienced person', 'Person'], dtype='<U20'),
#  array(['270959', 'juvenile person', 'Person'], dtype='<U15'),
#  array(['270960', 'loved one', 'Person'], dtype='<U11'),
#  array(['270961', 'male person', 'Person'], dtype='<U11'),
#  array(['270962', 'money dealer', 'Person'], dtype='<U12'),
#  array(['270963', 'money handler', 'Person'], dtype='<U13'),
#  array(['270964', 'nonreligious person', 'Person'], dtype='<U19'),
#  array(['270965', 'primitive person', 'Person'], dtype='<U16'),
#  array(['270966', 'religious person', 'Person'], dtype='<U16'),
#  array(['270967', 'unfortunate person', 'Person'], dtype='<U18'),
#  array(['270968', 'persona non grata', 'Person'], dtype='<U17'),
#  array(['270969', 'unwelcome person', 'Person'], dtype='<U16'),
#  array(['270970', 'unskilled person', 'Person'], dtype='<U16'),
#  array(['270971', 'person of color', 'Person'], dtype='<U15'),
#  array(['270972', 'person of colour', 'Person'], dtype='<U16'),
#  array(['270973', 'white person', 'Person'], dtype='<U12'),
#  array(['270974', 'native american', 'Person'], dtype='<U15'),
#  array(['270975', 'water bearer', 'Person'], dtype='<U12'),
#  array(['270976', 'india', 'Person'], dtype='<U11'),
#  array(['270977', 'syria', 'Person'], dtype='<U11'),
#  array(['270978', 'army', 'Person'], dtype='<U11'),
#  array(['270979', 'legal obligation', 'Person'], dtype='<U16'),
#  array(['270980', 'empire', 'Person'], dtype='<U11'),
#  array(['270981', 'slavery', 'Person'], dtype='<U11'),
#  array(['270982', 'greece', 'Person'], dtype='<U11'),
#  array(['270983', 'registrant', 'Person'], dtype='<U11'),
#  array(['270984', 'nominator', 'Person'], dtype='<U11'),
#  array(['270985', 'judaism', 'Person'], dtype='<U11'),
#  array(['270986', 'transferee', 'Person'], dtype='<U11'),
#  array(['270987', 'permittee', 'Person'], dtype='<U11'),
#  array(['270988', 'hinduism', 'Person'], dtype='<U11'),
#  array(['270989', 'cardholder', 'Person'], dtype='<U11'),
#  array(['270990', 'railway', 'Person'], dtype='<U11'),
#  array(['270991', 'electricity', 'Person'], dtype='<U11'),
#  array(['270992', 'personal identity', 'Person'], dtype='<U17'),
#  array(['270993', 'telephone', 'Person'], dtype='<U11'),
#  array(['270994', 'abortion', 'Person'], dtype='<U11'),
#  array(['270995', 'internet', 'Person'], dtype='<U11'),
#  array(['270996', 'pre-history', 'Person'], dtype='<U11'),
#  array(['270997', 'water', 'Person'], dtype='<U11'),
#  array(['270998', 'nature', 'Person'], dtype='<U11'),
#  array(['270999', 'transport', 'Person'], dtype='<U11'),
#  array(['271000', 'population', 'Person'], dtype='<U11'),
#  array(['271001', 'asia', 'Person'], dtype='<U11'),
#  array(['271002', 'africa', 'Person'], dtype='<U11'),
#  array(['271003', 'oceania', 'Person'], dtype='<U11'),
#  array(['271004', 'town', 'Person'], dtype='<U11'),
#  array(['271005', 'city', 'Person'], dtype='<U11'),
#  array(['271006', 'predator', 'Person'], dtype='<U11'),
#  array(['271007', 'ethnic group', 'Person'], dtype='<U12'),
#  array(['271008', 'industry', 'Person'], dtype='<U11'),
#  array(['271009', 'animals', 'Person'], dtype='<U11'),
#  array(['271010', 'hair', 'Person'], dtype='<U11'),
#  array(['271011', 'genitalia', 'Person'], dtype='<U11'),
#  array(['271012', 'head', 'Person'], dtype='<U11'),
#  array(['271013', 'chest', 'Person'], dtype='<U11'),
#  array(['271014', 'common chimpanzee', 'Person'], dtype='<U17'),
#  array(['271015', 'red', 'Person'], dtype='<U11'),
#  array(['271016', 'blond', 'Person'], dtype='<U11'),
#  array(['271017', 'corporations', 'Person'], dtype='<U12'),
#  array(['271018', 'grey', 'Person'], dtype='<U11'),
#  array(['271019', 'sahelanthropus tchadensis', 'Person'], dtype='<U25'),
#  array(['271020', 'skin', 'Person'], dtype='<U11'),
#  array(['271021', 'pink', 'Person'], dtype='<U11'),
#  array(['271022', 'melanin', 'Person'], dtype='<U11'),
#  array(['271023', 'ultraviolet', 'Person'], dtype='<U11'),
#  array(['271024', 'sunlight', 'Person'], dtype='<U11'),
#  array(['271025', 'great ape', 'Person'], dtype='<U11'),
#  array(['271026', 'homo habilis', 'Person'], dtype='<U12'),
#  array(['271027', 'polity', 'Person'], dtype='<U11'),
#  array(['271028', 'homo erectus', 'Person'], dtype='<U12'),
#  array(['271029', 'sahara pump theory', 'Person'], dtype='<U18'),
#  array(['271030', 'estate', 'Person'], dtype='<U11'),
#  array(['271031', 'east africa', 'Person'], dtype='<U11'),
#  array(['271032', 'sleep', 'Person'], dtype='<U11'),
#  array(['271033', 'health', 'Person'], dtype='<U11'),
#  array(['271034', 'group', 'Person'], dtype='<U11'),
#  array(['271035', 'equality before the law', 'Person'], dtype='<U23'),
#  array(['271036', 'probate', 'Person'], dtype='<U11'),
#  array(['271037', 'baby', 'Person'], dtype='<U11'),
#  array(['271038', 'vagina', 'Person'], dtype='<U11'),
#  array(['271039', 'bones', 'Person'], dtype='<U11'),
#  array(['271040', 'identity', 'Person'], dtype='<U11'),
#  array(['271041', 'natural person', 'Person'], dtype='<U14'),
#  array(['271042', 'medication', 'Person'], dtype='<U11'),
#  array(['271043', 'weight', 'Person'], dtype='<U11'),
#  array(['271044', 'kg', 'Person'], dtype='<U11'),
#  array(['271045', 'centimetre', 'Person'], dtype='<U11'),
#  array(['271046', 'children', 'Person'], dtype='<U11'),
#  array(['271047', 'legal personality', 'Person'], dtype='<U17'),
#  array(['271048', 'company', 'Person'], dtype='<U11'),
#  array(['271049', 'teenager', 'Person'], dtype='<U11'),
#  array(['271050', 'neolithic revolution', 'Person'], dtype='<U20'),
#  array(['271051', 'human settlement', 'Person'], dtype='<U16'),
#  array(['271052', 'monaco', 'Person'], dtype='<U11'),
#  array(['271053', 'biology', 'Person'], dtype='<U11'),
#  array(['271054', 'mind', 'Person'], dtype='<U11'),
#  array(['271055', 'legal liability', 'Person'], dtype='<U15'),
#  array(['271056', 'movement', 'Person'], dtype='<U11'),
#  array(['271057', 'breathing', 'Person'], dtype='<U11'),
#  array(['271058', 'linguistics', 'Person'], dtype='<U11'),
#  array(['271059', 'mammals', 'Person'], dtype='<U11'),
#  array(['271060', 'persona', 'Person'], dtype='<U11'),
#  array(['271061', 'ancient rome', 'Person'], dtype='<U12'),
#  array(['271062', 'neurology', 'Person'], dtype='<U11'),
#  array(['271063', 'psychology', 'Person'], dtype='<U11'),
#  array(['271064', "women's rights", 'Person'], dtype='<U14'),
#  array(['271065', 'writing', 'Person'], dtype='<U11'),
#  array(['271066', 'growth', 'Person'], dtype='<U11'),
#  array(['271067', 'team', 'Person'], dtype='<U11'),
#  array(['271068', 'medicine', 'Person'], dtype='<U11'),
#  array(['271069', 'prosopon', 'Person'], dtype='<U11'),
#  array(['271070', 'party', 'Person'], dtype='<U11'),
#  array(['271071', 'fetal rights', 'Person'], dtype='<U12'),
#  array(['271072', 'object', 'Person'], dtype='<U11'),
#  array(['271073', 'reading', 'Person'], dtype='<U11'),
#  array(['271074', 'organization', 'Person'], dtype='<U12'),
#  array(['271075', 'situation', 'Person'], dtype='<U11'),
#  array(['271076', 'dog', 'Person'], dtype='<U11'),
#  array(['271077', 'persons', 'Person'], dtype='<U11'),
#  array(['271078', 'the americas', 'Person'], dtype='<U12'),
#  array(['271079', 'christology', 'Person'], dtype='<U11'),
#  array(['271080', 'place', 'Person'], dtype='<U11'),
#  array(['271081', 'monster', 'Person'], dtype='<U11'),
#  array(['271082', 'business', 'Person'], dtype='<U11'),
#  array(['271083', 'online', 'Person'], dtype='<U11'),
#  array(['271084', 'syntax', 'Person'], dtype='<U11'),
#  array(['271085', 'animal rights', 'Person'], dtype='<U13'),
#  array(['271086', 'parent', 'Person'], dtype='<U11'),
#  array(['271087', 'vocabulary', 'Person'], dtype='<U11'),
#  array(['271088', 'bot', 'Person'], dtype='<U11'),
#  array(['271089', 'item', 'Person'], dtype='<U11'),
#  array(['271090', 'relationship', 'Person'], dtype='<U12'),
#  array(['271091', 'hybrid', 'Person'], dtype='<U11'),
#  array(['271092', 'the', 'Person'], dtype='<U11'),
#  array(['271093', 'vehicle', 'Person'], dtype='<U11'),
#  array(['271094', 'other', 'Person'], dtype='<U11'),
#  array(['271095', 'kid', 'Person'], dtype='<U11'),
#  array(['271096', 'owner', 'Person'], dtype='<U11'),
#  array(['271097', 'their', 'Person'], dtype='<U11'),
#  array(['271098', 'living', 'Person'], dtype='<U11'),
#  array(['271099', 'body', 'Person'], dtype='<U11'),
#  array(['271100', 'job', 'Person'], dtype='<U11'),
#  array(['271101', 'department', 'Person'], dtype='<U11'),
#  array(['271102', 'celebrity', 'Person'], dtype='<U11'),
#  array(['271103', 'gamer', 'Person'], dtype='<U11'),
#  array(['271104', 'have', 'Person'], dtype='<U11'),
#  array(['271105', 'student', 'Person'], dtype='<U11'),
#  array(['271106', 'video', 'Person'], dtype='<U11'),
#  array(['271107', 'pet', 'Person'], dtype='<U11'),
#  array(['271108', 'faction', 'Person'], dtype='<U11'),
#  array(['271109', 'account', 'Person'], dtype='<U11'),
#  array(['271110', 'cases', 'Person'], dtype='<U11'),
#  array(['271111', 'corporation', 'Person'], dtype='<U11'),
#  array(['271112', 'some', 'Person'], dtype='<U11'),
#  array(['271113', 'poc', 'Person'], dtype='<U11'),
#  array(['271114', 'org', 'Person'], dtype='<U11'),
#  array(['271115', 'via', 'Person'], dtype='<U11'),
#  array(['271116', 'crush', 'Person'], dtype='<U11'),
#  array(['271117', 'side', 'Person'], dtype='<U11'),
#  array(['271118', 'what', 'Person'], dtype='<U11'),
#  array(['271119', 'organisation', 'Person'], dtype='<U12'),
#  array(['271120', 'household', 'Person'], dtype='<U11'),
#  array(['271121', 'boyfriend', 'Person'], dtype='<U11'),
#  array(['271122', 'institution', 'Person'], dtype='<U11'),
#  array(['271123', 'event', 'Person'], dtype='<U11'),
#  array(['271124', 'cop', 'Person'], dtype='<U11'),
#  array(['271125', 'professional', 'Person'], dtype='<U12'),
#  array(['271126', 'store', 'Person'], dtype='<U11'),
#  array(['271127', 'coach', 'Person'], dtype='<U11'),
#  array(['271128', 'ppl', 'Person'], dtype='<U11'),
#  array(['271129', 'phone', 'Person'], dtype='<U11'),
#  array(['271130', 'you', 'Person'], dtype='<U11'),
#  array(['271131', 'past', 'Person'], dtype='<U11'),
#  array(['271132', 'time', 'Person'], dtype='<U11'),
#  array(['271133', 'partner', 'Person'], dtype='<U11'),
#  array(['271134', 'artist', 'Person'], dtype='<U11'),
#  array(['271135', 'first', 'Person'], dtype='<U11'),
#  array(['271136', 'topic', 'Person'], dtype='<U11'),
#  array(['271137', 'deaths', 'Person'], dtype='<U11'),
#  array(['271138', 'posse', 'Person'], dtype='<U11'),
#  array(['271139', 'united nations', 'Person'], dtype='<U14'),
#  array(['271140', 'school', 'Person'], dtype='<U11'),
#  array(['271141', 'mentor', 'Person'], dtype='<U11'),
#  array(['271142', 'residence', 'Person'], dtype='<U11'),
#  array(['271143', 'hiring', 'Person'], dtype='<U11'),
#  array(['271144', 'robot', 'Person'], dtype='<U11'),
#  array(['271145', 'credible', 'Person'], dtype='<U11'),
#  array(['271146', 'computer', 'Person'], dtype='<U11'),
#  array(['271147', 'name', 'Person'], dtype='<U11'),
#  array(['271148', 'great', 'Person'], dtype='<U11'),
#  array(['271149', 'idol', 'Person'], dtype='<U11'),
#  array(['271150', 'position', 'Person'], dtype='<U11'),
#  array(['271151', 'site', 'Person'], dtype='<U11'),
#  array(['271152', 'bad', 'Person'], dtype='<U11'),
#  array(['271153', 'love', 'Person'], dtype='<U11'),
#  array(['271154', 'committee', 'Person'], dtype='<U11'),
#  array(['271155', 'story', 'Person'], dtype='<U11'),
#  array(['271156', 'society', 'Person'], dtype='<U11'),
#  array(['271157', 'teacher', 'Person'], dtype='<U11'),
#  array(['271158', 'these', 'Person'], dtype='<U11'),
#  array(['271159', 'multiple', 'Person'], dtype='<U11'),
#  array(['271160', 'race', 'Person'], dtype='<U11'),
#  array(['271161', 'renter', 'Person'], dtype='<U11'),
#  array(['271162', 'rapper', 'Person'], dtype='<U11'),
#  array(['271163', 'second', 'Person'], dtype='<U11'),
#  array(['271164', 'groups', 'Person'], dtype='<U11'),
#  array(['271165', 'streamer', 'Person'], dtype='<U11'),
#  array(['271166', 'troll', 'Person'], dtype='<U11'),
#  array(['271167', 'website', 'Person'], dtype='<U11'),
#  array(['271168', 'poster', 'Person'], dtype='<U11'),
#  array(['271169', 'resource', 'Person'], dtype='<U11'),
#  array(['271170', 'photo', 'Person'], dtype='<U11'),
#  array(['271171', 'writer', 'Person'], dtype='<U11'),
#  array(['271172', 'gay', 'Person'], dtype='<U11'),
#  array(['271173', 'third', 'Person'], dtype='<U11'),
#  array(['271174', 'club', 'Person'], dtype='<U11'),
#  array(['271175', 'over', 'Person'], dtype='<U11'),
#  array(['271176', 'better', 'Person'], dtype='<U11'),
#  array(['271177', 'per', 'Person'], dtype='<U11'),
#  array(['271178', 'shop', 'Person'], dtype='<U11'),
#  array(['271179', 'interaction', 'Person'], dtype='<U11'),
#  array(['271180', 'lawyer', 'Person'], dtype='<U11'),
#  array(['271181', 'many', 'Person'], dtype='<U11'),
#  array(['271182', 'service', 'Person'], dtype='<U11'),
#  array(['271183', 'doctor', 'Person'], dtype='<U11'),
#  array(['271184', 'stealth', 'Person'], dtype='<U11'),
#  array(['271185', 'more', 'Person'], dtype='<U11'),
#  array(['271186', 'mom', 'Person'], dtype='<U11'),
#  array(['271187', 'guild', 'Person'], dtype='<U11'),
#  array(['271188', 'artefact', 'Person'], dtype='<U11'),
#  array(['271189', 'has', 'Person'], dtype='<U11'),
#  array(['271190', 'dept', 'Person'], dtype='<U11'),
#  array(['271191', 'lifestyle', 'Person'], dtype='<U11'),
#  array(['271192', 'sister', 'Person'], dtype='<U11'),
#  array(['271193', 'early', 'Person'], dtype='<U11'),
#  array(['271194', 'president', 'Person'], dtype='<U11'),
#  array(['271195', 'girlfriend', 'Person'], dtype='<U11'),
#  array(['271196', 'cockpit', 'Person'], dtype='<U11'),
#  array(['271197', 'dangerous', 'Person'], dtype='<U11'),
#  array(['271198', 'obesity', 'Person'], dtype='<U11'),
#  array(['271199', 'restorer', 'Person'], dtype='<U11'),
#  array(['271200', 'snaps', 'Person'], dtype='<U11'),
#  array(['271201', 'action', 'Person'], dtype='<U11'),
#  array(['271202', 'claudette', 'Person'], dtype='<U11'),
#  array(['271203', 'surface', 'Person'], dtype='<U11'),
#  array(['271204', 'below', 'Person'], dtype='<U11'),
#  array(['271205', 'drink', 'Person'], dtype='<U11'),
#  array(['271206', 'studio', 'Person'], dtype='<U11'),
#  array(['271207', 'day', 'Person'], dtype='<U11'),
#  array(['271208', 'shortcomings', 'Person'], dtype='<U12'),
#  array(['271209', 'toxic', 'Person'], dtype='<U11'),
#  array(['271210', 'corporate', 'Person'], dtype='<U11'),
#  array(['271211', 'bottle', 'Person'], dtype='<U11'),
#  array(['271212', 'stand', 'Person'], dtype='<U11'),
#  array(['271213', 'program', 'Person'], dtype='<U11'),
#  array(['271214', 'serving', 'Person'], dtype='<U11'),
#  array(['271215', 'her', 'Person'], dtype='<U11'),
#  array(['271216', 'history', 'Person'], dtype='<U11'),
#  array(['271217', 'post', 'Person'], dtype='<U11'),
#  array(['271218', 'brand', 'Person'], dtype='<U11'),
#  array(['271219', 'dead', 'Person'], dtype='<U11'),
#  array(['271220', 'hands', 'Person'], dtype='<U11'),
#  array(['271221', 'non human', 'Person'], dtype='<U11'),
#  array(['271222', 'boethius', 'Person'], dtype='<U11'),
#  array(['271223', 'united states', 'Person'], dtype='<U13'),
#  array(['271224', 'painting', 'Person'], dtype='<U11'),
#  array(['271225', 'sculpture', 'Person'], dtype='<U11'),
#  array(['271226', 'photograph', 'Person'], dtype='<U11'),
#  array(['271227', 'drums', 'Person'], dtype='<U11'),
#  array(['271228', 'violin', 'Person'], dtype='<U11'),
#  array(['271229', 'books', 'Person'], dtype='<U11'),
#  array(['271230', 'poetry', 'Person'], dtype='<U11'),
#  array(['271231', 'legend', 'Person'], dtype='<U11'),
#  array(['271232', 'myths', 'Person'], dtype='<U11'),
#  array(['271233', 'wikipedia', 'Person'], dtype='<U11'),
#  array(['271234', 'gene', 'Person'], dtype='<U11'),
#  array(['271235', 'racism', 'Person'], dtype='<U11'),
#  array(['271236', 'religion', 'Person'], dtype='<U11'),
#  array(['271237', 'belief', 'Person'], dtype='<U11'),
#  array(['271238', 'faith', 'Person'], dtype='<U11'),
#  array(['271239', 'religious', 'Person'], dtype='<U11'),
#  array(['271240', 'god', 'Person'], dtype='<U11'),
#  array(['271241', 'atheism', 'Person'], dtype='<U11'),
#  array(['271242', 'agnosticism', 'Person'], dtype='<U11'),
#  array(['271243', 'universe', 'Person'], dtype='<U11'),
#  array(['271244', 'telescope', 'Person'], dtype='<U11'),
#  array(['271245', 'galileo', 'Person'], dtype='<U11'),
#  array(['271246', 'lasers', 'Person'], dtype='<U11'),
#  array(['271247', 'computing', 'Person'], dtype='<U11'),
#  array(['271248', 'state', 'Person'], dtype='<U11'),
#  array(['271249', 'soldiers', 'Person'], dtype='<U11'),
#  array(['271250', 'terrorism', 'Person'], dtype='<U11'),
#  array(['271251', 'propaganda', 'Person'], dtype='<U11'),
#  array(['271252', 'hiroshima', 'Person'], dtype='<U11'),
#  array(['271253', 'nagasaki', 'Person'], dtype='<U11'),
#  array(['271254', 'food chain', 'Person'], dtype='<U11'),
#  array(['271255', 'neocortex', 'Person'], dtype='<U11'),
#  array(['271256', 'climate change', 'Person'], dtype='<U14'),
#  array(['271257', 'human height', 'Person'], dtype='<U12'),
#  array(['271258', 'artificial intelligences', 'Person'], dtype='<U24'),
#  array(['271259', 'extraterrestrial life', 'Person'], dtype='<U21'),
#  array(['271260', 'trinitarianism', 'Person'], dtype='<U14'),
#  array(['271261', 'sovereign states', 'Person'], dtype='<U16'),
#  array(['271262', 'skin cancer', 'Person'], dtype='<U11'),
#  array(['271263', 'celeb', 'Person'], dtype='<U11'),
#  array(['271264', 'polititian', 'Person'], dtype='<U11'),
#  array(['271265', 'mljr', 'Person'], dtype='<U11'),
#  array(['271266', 'natural selection', 'Person'], dtype='<U17'),
#  array(['271267', 'philosophy of mind', 'Person'], dtype='<U18'),
#  array(['271268', 'continental philosophy', 'Person'], dtype='<U22'),
#  array(['271269', 'old age', 'Person'], dtype='<U11'),
#  array(['271270', 'life expectancy', 'Person'], dtype='<U15'),
#  array(['271271', 'analytic philosophy', 'Person'], dtype='<U19'),
#  array(['271272', 'bundle theory', 'Person'], dtype='<U13'),
#  array(['271273', 'hormone system', 'Person'], dtype='<U14'),
#  array(['271274', 'pituitary gland', 'Person'], dtype='<U15'),
#  array(['271275', 'ancient greek language', 'Person'], dtype='<U22'),
#  array(['271276', 'computer science', 'Person'], dtype='<U16'),
#  array(['271277', 'first language', 'Person'], dtype='<U14'),
#  array(['271278', 'mandarin chinese', 'Person'], dtype='<U16'),
#  array(['271279', 'second language', 'Person'], dtype='<U15'),
#  array(['271280', 'romanization of ancient greek', 'Person'], dtype='<U29'),
#  array(['271281', 'theatre of ancient greece', 'Person'], dtype='<U25'),
#  array(['271282', 'john locke', 'Person'], dtype='<U11'),
#  array(['271283', 'immanuel kant', 'Person'], dtype='<U13'),
#  array(['271284', 'lynne baker', 'Person'], dtype='<U11'),
#  array(['271285', 'musical instrument', 'Person'], dtype='<U18'),
#  array(['271286', 'electric guitar', 'Person'], dtype='<U15'),
#  array(['271287', 'keyboard instrument', 'Person'], dtype='<U19'),
#  array(['271288', 'fairy tale', 'Person'], dtype='<U11'),
#  array(['271289', 'creation myth', 'Person'], dtype='<U13'),
#  array(['271290', 'albert einstein', 'Person'], dtype='<U15'),
#  array(['271291', 'theory of relativity', 'Person'], dtype='<U20'),
#  array(['271292', 'guerrilla warfare', 'Person'], dtype='<U17'),
#  array(['271293', 'nuclear bomb', 'Person'], dtype='<U12'),
#  array(['271294', 'world war ii', 'Person'], dtype='<U12'),
#  array(['271295', 'acute radiation syndrome', 'Person'], dtype='<U24'),
#  array(['271296', 'animal', 'Person'], dtype='<U11'),
#  array(['271297', 'dog', 'Person'], dtype='<U11'),
#  array(['271298', 'cat', 'Person'], dtype='<U11'),
#  array(['271299', 'bird', 'Person'], dtype='<U11'),
#  array(['271300', 'puppy', 'Person'], dtype='<U11'),
#  array(['271301', 'favorite', 'Person'], dtype='<U11'),
#  array(['271302', 'favourite', 'Person'], dtype='<U11'),
#  array(['271303', 'darling', 'Person'], dtype='<U11'),
#  array(['271304', 'favored', 'Person'], dtype='<U11'),
#  array(['271305', 'rottweiler', 'Person'], dtype='<U11'),
#  array(['271306', 'loved', 'Person'], dtype='<U11'),
#  array(['271307', 'fondle', 'Person'], dtype='<U11'),
#  array(['271308', 'caress', 'Person'], dtype='<U11'),
#  array(['271309', 'rabbit', 'Person'], dtype='<U11'),
#  array(['271310', 'eat', 'Person'], dtype='<U11'),
#  array(['271311', 'preferred', 'Person'], dtype='<U11'),
#  array(['271312', 'dearie', 'Person'], dtype='<U11'),
#  array(['271313', 'deary', 'Person'], dtype='<U11'),
#  array(['271314', 'ducky', 'Person'], dtype='<U11'),
#  array(['271315', 'rodent', 'Person'], dtype='<U11'),
#  array(['271316', 'turtle', 'Person'], dtype='<U11'),
#  array(['271317', 'positron emission tomography', 'Person'], dtype='<U28'),
#  array(['271318', 'goldfish', 'Person'], dtype='<U11'),
#  array(['271319', 'livestock', 'Person'], dtype='<U11'),
#  array(['271320', 'kennel', 'Person'], dtype='<U11'),
#  array(['271321', 'greyhound', 'Person'], dtype='<U11'),
#  array(['271322', 'hamster', 'Person'], dtype='<U11'),
#  array(['271323', 'beagle', 'Person'], dtype='<U11'),
#  array(['271324', 'spaniel', 'Person'], dtype='<U11'),
#  array(['271325', 'poodle', 'Person'], dtype='<U11'),
#  array(['271326', 'corgi', 'Person'], dtype='<U11'),
#  array(['271327', 'foxhound', 'Person'], dtype='<U11'),
#  array(['271328', 'doggie', 'Person'], dtype='<U11'),
#  array(['271329', 'pomeranian', 'Person'], dtype='<U11'),
#  array(['271330', 'elephant', 'Person'], dtype='<U11'),
#  array(['271331', 'dachshund', 'Person'], dtype='<U11'),
#  array(['271332', 'collie', 'Person'], dtype='<U11'),
#  array(['271333', 'pup', 'Person'], dtype='<U11'),
#  array(['271334', 'schipperke', 'Person'], dtype='<U11'),
#  array(['271335', 'schnauzer', 'Person'], dtype='<U11'),
#  array(['271336', 'yorkie', 'Person'], dtype='<U11'),
#  array(['271337', 'animal-assisted therapy', 'Person'], dtype='<U23'),
#  array(['271338', 'miniature pinscher', 'Person'], dtype='<U18'),
#  array(['271339', 'fox terrier', 'Person'], dtype='<U11'),
#  array(['271340', 'golden retriever', 'Person'], dtype='<U16'),
#  array(['271341', 'irish setter', 'Person'], dtype='<U12'),
#  array(['271342', 'shetland sheepdog', 'Person'], dtype='<U17'),
#  array(['271343', 'basset hound', 'Person'], dtype='<U12'),
#  array(['271344', 'shih tzu', 'Person'], dtype='<U11'),
#  array(['271345', 'lhasa apso', 'Person'], dtype='<U11'),
#  array(['271346', 'labrador retriever', 'Person'], dtype='<U18'),
#  array(['271347', 'cocker spaniel', 'Person'], dtype='<U14'),
#  array(['271348', 'airedale terrier', 'Person'], dtype='<U16'),
#  array(['271349', 'french bulldog', 'Person'], dtype='<U14'),
#  array(['271350', 'great dane', 'Person'], dtype='<U11'),
#  array(['271351', 'guinea pig', 'Person'], dtype='<U11'),
#  array(['271352', 'rat', 'Person'], dtype='<U11'),
#  array(['271353', 'monkey', 'Person'], dtype='<U11'),
#  array(['271354', 'mouse', 'Person'], dtype='<U11'),
#  array(['271355', 'kitten', 'Person'], dtype='<U11'),
#  array(['271356', 'veterinarian', 'Person'], dtype='<U12'),
#  array(['271357', 'pug', 'Person'], dtype='<U11'),
#  array(['271358', 'domestication', 'Person'], dtype='<U13'),
#  array(['271359', 'preferent', 'Person'], dtype='<U11'),
#  array(['271360', 'best-loved', 'Person'], dtype='<U11'),
#  array(['271361', 'labour', 'Person'], dtype='<U11'),
#  array(['271362', 'peevishness', 'Person'], dtype='<U11'),
#  array(['271363', 'irritability', 'Person'], dtype='<U12'),
#  array(['271364', 'neck', 'Person'], dtype='<U11'),
#  array(['271365', 'chosen', 'Person'], dtype='<U11'),
#  array(['271366', 'choler', 'Person'], dtype='<U11'),
#  array(['271367', 'lover', 'Person'], dtype='<U11'),
#  array(['271368', 'fauna', 'Person'], dtype='<U11'),
#  array(['271369', 'gentle', 'Person'], dtype='<U11'),
#  array(['271370', 'creature', 'Person'], dtype='<U11'),
#  array(['271371', 'petulance', 'Person'], dtype='<U11'),
#  array(['271372', 'beast', 'Person'], dtype='<U11'),
#  array(['271373', 'fretfulness', 'Person'], dtype='<U11'),
#  array(['271374', 'tomography', 'Person'], dtype='<U11'),
#  array(['271375', 'imaging', 'Person'], dtype='<U11'),
#  array(['271376', 'brute', 'Person'], dtype='<U11'),
#  array(['271377', 'purebred', 'Person'], dtype='<U11'),
#  array(['271378', 'ferret', 'Person'], dtype='<U11'),
#  array(['271379', 'fido', 'Person'], dtype='<U11'),
#  array(['271380', 'gerbil', 'Person'], dtype='<U11'),
#  array(['271381', 'rex', 'Person'], dtype='<U11'),
#  array(['271382', 'chinchilla', 'Person'], dtype='<U11'),
#  array(['271383', 'deerhound', 'Person'], dtype='<U11'),
#  array(['271384', 'canis', 'Person'], dtype='<U11'),
#  array(['271385', 'griffon', 'Person'], dtype='<U11'),
#  array(['271386', 'sheepdog', 'Person'], dtype='<U11'),
#  array(['271387', 'doggedly', 'Person'], dtype='<U11'),
#  array(['271388', 'doggedness', 'Person'], dtype='<U11'),
#  array(['271389', 'whippet', 'Person'], dtype='<U11'),
#  array(['271390', 'dogger', 'Person'], dtype='<U11'),
#  array(['271391', 'lurcher', 'Person'], dtype='<U11'),
#  array(['271392', 'doggy', 'Person'], dtype='<U11'),
#  array(['271393', 'retriever', 'Person'], dtype='<U11'),
#  array(['271394', 'cur', 'Person'], dtype='<U11'),
#  array(['271395', 'pertinaciously', 'Person'], dtype='<U14'),
#  array(['271396', 'akita', 'Person'], dtype='<U11'),
#  array(['271397', 'doghouse', 'Person'], dtype='<U11'),
#  array(['271398', 'flea', 'Person'], dtype='<U11'),
#  array(['271399', 'dingo', 'Person'], dtype='<U11'),
#  array(['271400', 'bloodhound', 'Person'], dtype='<U11'),
#  array(['271401', 'macushla', 'Person'], dtype='<U11'),
#  array(['271402', 'fussiness', 'Person'], dtype='<U11'),
#  array(['271403', 'mollycoddle', 'Person'], dtype='<U11'),
#  array(['271404', 'canoodle', 'Person'], dtype='<U11'),
#  array(['271405', 'crossness', 'Person'], dtype='<U11'),
#  array(['271406', 'canine', 'Person'], dtype='<U11'),
#  array(['271407', 'dogcart', 'Person'], dtype='<U11'),
#  array(['271408', 'spitz', 'Person'], dtype='<U11'),
#  array(['271409', 'antidog', 'Person'], dtype='<U11'),
#  array(['271410', 'pulegone', 'Person'], dtype='<U11'),
#  array(['271411', 'pets', 'Person'], dtype='<U11'),
#  array(['271412', 'hemangiosarcoma', 'Person'], dtype='<U15'),
#  array(['271413', 'parakeet', 'Person'], dtype='<U11'),
#  array(['271414', 'parrot', 'Person'], dtype='<U11'),
#  array(['271415', 'multidog', 'Person'], dtype='<U11'),
#  array(['271416', 'cefovecin', 'Person'], dtype='<U11'),
#  array(['271417', 'furkid', 'Person'], dtype='<U11'),
#  array(['271418', 'ratter', 'Person'], dtype='<U11'),
#  array(['271419', 'fish', 'Person'], dtype='<U11'),
#  array(['271420', 'lizard', 'Person'], dtype='<U11'),
#  array(['271421', 'baby', 'Person'], dtype='<U11'),
#  array(['271422', 'dognap', 'Person'], dtype='<U11'),
#  array(['271423', 'snake', 'Person'], dtype='<U11'),
#  array(['271424', 'demiwolf', 'Person'], dtype='<U11'),
#  array(['271425', 'harehound', 'Person'], dtype='<U11'),
#  array(['271426', 'dogling', 'Person'], dtype='<U11'),
#  array(['271427', 'dognapping', 'Person'], dtype='<U11'),
#  array(['271428', 'dogsitter', 'Person'], dtype='<U11'),
#  array(['271429', 'trundletail', 'Person'], dtype='<U11'),
#  array(['271430', 'dogdom', 'Person'], dtype='<U11'),
#  array(['271431', 'aquarium', 'Person'], dtype='<U11'),
#  array(['271432', 'coonhound', 'Person'], dtype='<U11'),
#  array(['271433', 'dogophile', 'Person'], dtype='<U11'),
#  array(['271434', 'crocotta', 'Person'], dtype='<U11'),
#  array(['271435', 'robodog', 'Person'], dtype='<U11'),
#  array(['271436', 'dhole', 'Person'], dtype='<U11'),
#  array(['271437', 'dogbane', 'Person'], dtype='<U11'),
#  array(['271438', 'lapdog', 'Person'], dtype='<U11'),
#  array(['271439', 'basenji', 'Person'], dtype='<U11'),
#  array(['271440', 'dogberryism', 'Person'], dtype='<U11'),
#  array(['271441', 'doglore', 'Person'], dtype='<U11'),
#  array(['271442', 'cyno', 'Person'], dtype='<U11'),
#  array(['271443', 'dogless', 'Person'], dtype='<U11'),
#  array(['271444', 'coondog', 'Person'], dtype='<U11'),
#  array(['271445', 'canid', 'Person'], dtype='<U11'),
#  array(['271446', 'granddog', 'Person'], dtype='<U11'),
#  array(['271447', 'corndog', 'Person'], dtype='<U11'),
#  array(['271448', 'lucern', 'Person'], dtype='<U11'),
#  array(['271449', 'rottie', 'Person'], dtype='<U11'),
#  array(['271450', 'briard', 'Person'], dtype='<U11'),
#  array(['271451', 'sleuthhound', 'Person'], dtype='<U11'),
#  array(['271452', 'elkhound', 'Person'], dtype='<U11'),
#  array(['271453', 'doggishly', 'Person'], dtype='<U11'),
#  array(['271454', 'adamance', 'Person'], dtype='<U11'),
#  array(['271455', 'coydog', 'Person'], dtype='<U11'),
#  array(['271456', 'seadog', 'Person'], dtype='<U11'),
#  array(['271457', 'doggily', 'Person'], dtype='<U11'),
#  array(['271458', 'doghood', 'Person'], dtype='<U11'),
#  array(['271459', 'doggishness', 'Person'], dtype='<U11'),
#  array(['271460', 'dogs', 'Person'], dtype='<U11'),
#  array(['271461', 'doggish', 'Person'], dtype='<U11'),
#  array(['271462', 'labradoodle', 'Person'], dtype='<U11'),
#  array(['271463', 'saluki', 'Person'], dtype='<U11'),
#  array(['271464', 'dogly', 'Person'], dtype='<U11'),
#  array(['271465', 'poochie', 'Person'], dtype='<U11'),
#  array(['271466', 'spurdog', 'Person'], dtype='<U11'),
#  array(['271467', 'staghound', 'Person'], dtype='<U11'),
#  array(['271468', 'pig', 'Person'], dtype='<U11'),
#  array(['271469', 'doglike', 'Person'], dtype='<U11'),
#  array(['271470', 'otterhound', 'Person'], dtype='<U11'),
#  array(['271471', 'bandog', 'Person'], dtype='<U11'),
#  array(['271472', 'dogcatcher', 'Person'], dtype='<U11'),
#  array(['271473', 'yorkipoo', 'Person'], dtype='<U11'),
#  array(['271474', 'coachdog', 'Person'], dtype='<U11'),
#  array(['271475', 'leamer', 'Person'], dtype='<U11'),
#  array(['271476', 'toys', 'Person'], dtype='<U11'),
#  array(['271477', 'weredog', 'Person'], dtype='<U11'),
#  array(['271478', 'cow', 'Person'], dtype='<U11'),
#  array(['271479', 'cats', 'Person'], dtype='<U11'),
#  array(['271480', 'drever', 'Person'], dtype='<U11'),
#  array(['271481', 'cynophilia', 'Person'], dtype='<U11'),
#  array(['271482', 'utonagan', 'Person'], dtype='<U11'),
#  array(['271483', 'samoyed', 'Person'], dtype='<U11'),
#  array(['271484', 'cynanthropy', 'Person'], dtype='<U11'),
#  array(['271485', 'frog', 'Person'], dtype='<U11'),
#  array(['271486', 'eating', 'Person'], dtype='<U11'),
#  array(['271487', 'working animal', 'Person'], dtype='<U14'),
#  array(['271488', 'bug', 'Person'], dtype='<U11'),
#  array(['271489', 'toy', 'Person'], dtype='<U11'),
#  array(['271490', 'babies', 'Person'], dtype='<U11'),
#  array(['271491', 'animals', 'Person'], dtype='<U11'),
#  array(['271492', 'arthropod', 'Person'], dtype='<U11'),
#  array(['271493', 'sport animal', 'Person'], dtype='<U12'),
#  array(['271494', 'candy', 'Person'], dtype='<U11'),
#  array(['271495', 'pigs', 'Person'], dtype='<U11'),
#  array(['271496', 'tarantula', 'Person'], dtype='<U11'),
#  array(['271497', 'treats', 'Person'], dtype='<U11'),
#  array(['271498', 'food', 'Person'], dtype='<U11'),
#  array(['271499', 'cloned', 'Person'], dtype='<U11'),
#  array(['271500', 'laboratory animal', 'Person'], dtype='<U17'),
#  array(['271501', 'rats', 'Person'], dtype='<U11'),
#  ...]

# %%
person_word[0].shape
# Out:
# (3,)

# %%
topic_modeling_df = np.append(topic_modeling_df, person_word)
# for i in person_word:
#     topic_modeling_df = np.append(topic_modeling_df, i, axis=0)

# %%
topic_modeling_df.shape
# Out:
# (922506,)

# %%
topic_modeling_df = topic_modeling_df.reshape(topic_modeling_df.shape[0] // 3, 3)

# %%
topic_modeling_df = pd.DataFrame(topic_modeling_df, columns=["Indexs", "word", "topic"])
topic_modeling_df
# Out:
#         Indexs                  word             topic
# 0            0             algorithm  Computer Science
# 1            1           mathematics  Computer Science
# 2            2  computer engineering  Computer Science
# 3            3               science  Computer Science
# 4            4                   ibm  Computer Science
# ...        ...                   ...               ...
# 307497  307497             job house            Person
# 307498  307498              sell off            Person
# 307499  307499         merchant bank            Person
# 307500  307500           grey market            Person
# 307501  307501            fannie mae            Person
#
# [307502 rows x 3 columns]

# %%
topic_modeling_df.drop("Indexs", axis=1, inplace=True)

# %%
topic_modeling_df
# Out:
#                         word             topic
# 0                  algorithm  Computer Science
# 1                mathematics  Computer Science
# 2       computer engineering  Computer Science
# 3                    science  Computer Science
# 4                        ibm  Computer Science
# ...                      ...               ...
# 307497             job house            Person
# 307498              sell off            Person
# 307499         merchant bank            Person
# 307500           grey market            Person
# 307501            fannie mae            Person
#
# [307502 rows x 2 columns]

# %%
topic_modeling_df.to_csv("./topic_modeling.csv")
